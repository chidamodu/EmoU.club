# %%
import os
os.getcwd()
os.chdir('/Users/chidam/Desktop')

# %%
#Viterbi algorithm - HMM - going with the original algorithm without altering
import math
from nltk.corpus import stopwords
import pandas as pd
import re
from collections import defaultdict
import nltk
#from nltk.corpus import stopwords

def reading_file(document): 
    filtered_sentence=[]
    res = defaultdict(list)
    df=pd.read_csv(document, names=['City', 'Details'], header=None, encoding='latin-1')
    #df=pd.read_csv('/Users/chidam/Desktop/data_trial_hmm_viterbi.csv', names=['City', 'Details'], header=None)
    df['Details'] = df['Details'].str.replace(',', ' ')
    #print(df.head())
    for i, j in df.itertuples(index=False):
        #print(i)
        s=re.split(r'(?<=\.) ', j )
        tag_sent=[nltk.word_tokenize(i) for i in s]
        pos_tag_sent=[nltk.pos_tag(sent) for sent in tag_sent]
        #res[i].append([[i] for i in s])
        #print(tag_sent)
        res[i].append(pos_tag_sent)
    return (res)


def hmm_viterbi(doc):
    len_tagged_doc=len(doc)
    #print(len_tagged_doc)
#     for line in doc:
#         len_tagged_doc=[x for x in line]
    transition_prob={}
    word_tag_prob={}
    max_of_tag_for_word={}
    
    tag_list=[]
    #tag_list*=len_tagged_doc
    word_list=[]
    #word_list*=len_tagged_doc
    result=[]

    for k in doc:#this is the key in the dictionary like New York
        for vita in doc[k]:#this is the blob of text - here it's in the form of list os lists containing tuples of words and tags
            for line in vita:
                result.append(line)
                for elem in line:
                    word_list.append(elem[0])
                    tag_list.append(elem[1])
                    
    for i in range (len(tag_list)):
        if (i+1) < (len(tag_list)):
            current_tag=tag_list[i+1]#inner: inner key of the transition_prob dictionary 
            #print(current_tag)
            
            previous_tag=tag_list[i]#outer: outer key of the transition_prob dictionary
            transition_prob[previous_tag]=transition_prob.get(previous_tag, {})
            transition_prob[previous_tag][current_tag]=transition_prob[previous_tag].get(current_tag, 0)
            transition_prob[previous_tag][current_tag]+=1
        
        #setting up the word-tag dictionary to get the word likelihood probability
            word_key=word_list[i]#outer: outer key of the word_tag_prob dictionary
            tag_key=tag_list[i]#inner: inner key of the word_tag_prob dictionary
            word_tag_prob[word_key]=word_tag_prob.get(word_key, {})
            word_tag_prob[word_key][tag_key]=word_tag_prob[word_key].get(tag_key, 0)
            word_tag_prob[word_key][tag_key]+=1
        
#         #to account for first word after '.'
    transition_prob['.'] = transition_prob.get('.',{})
    transition_prob['.'][tag_list[0]] = transition_prob['.'].get(tag_list[0],0)
        #print(tag_list[0])
    transition_prob['.'][tag_list[0]]+=1
    #print(transition_prob['.'][tag_list[0]])
        
        #last word_tag pair
    last_word_tag_index=len_tagged_doc-1
        
    last_word_key=word_list[last_word_tag_index]#outer key of the word_tag_prob dictionary
    last_tag_key=tag_list[last_word_tag_index]#inner key of the word_tag_prob dictionary
    word_tag_prob[last_word_key]=word_tag_prob.get(last_word_key, {})
    word_tag_prob[last_word_key][last_tag_key]=word_tag_prob[last_word_key].get(last_tag_key, 0)
    word_tag_prob[last_word_key][last_tag_key]+=1

    #calculating probabilities using the count-values from the dictionaries and assigning them back to the dictionary.so now we have probabilities for tags dictionary instead of counts  
    for k in transition_prob:
        ans=transition_prob[k]
        s=sum(ans.values())
    #print("all the values of the key {} are: {}". format(k, s))
        for j in ans:
            ans[j]= round(ans[j]/s, 1)
        ans=ans.items()
        ans=sorted(ans,key=lambda x: x[0])
        transition_prob[k]=ans

    
    #calculating probabilities for word-tag dictionary (it's just a dictionary with words and their associated tags. here i find probability of the tags associated with their words. if a word has more than one tag means the word has appeared more than once!)
    for key in word_tag_prob:
        aw=word_tag_prob[key]
        max_of_tag_for_word[key]=max(aw, key=aw.get)
        su=sum(aw.values())
        for ele in aw:
            aw[ele]= round(aw[ele]/su, 1)
        aw=aw.items()
        aw=sorted(aw, key=lambda x: x[0])
        word_tag_prob[key]=aw
    
    
    
#     by transition_prob i mean transition from one state(tag) to another state and probabilities of the same    
#     max_of_tag_for_word : (meaning getting the tag that has maximum probability and assigning that to the word from every word-tag list)
    return( word_tag_prob, transition_prob, word_list, tag_list, result)
    #return( word_tag_prob)
        
#reading_file('/Users/chidam/Desktop/data_trial_hmm_viterbi.csv')
hmm_viterbi(reading_file('/Users/chidam/Desktop/Barcelona.csv'))
# Out:
# ({'local': [('JJ', 1.0)],
#   'put': [('VBD', 1.0)],
#   'really': [('RB', 1.0)],
#   'Magos': [('NNP', 1.0)],
#   'inhabitants': [('NNS', 1.0)],
#   'falls': [('VBZ', 1.0)],
#   'legs': [('NNS', 1.0)],
#   'covered': [('VBN', 1.0)],
#   'craziest': [('JJS', 1.0)],
#   'away': [('RB', 0.5), ('RP', 0.5)],
#   'European': [('JJ', 1.0)],
#   'create': [('VB', 1.0)],
#   'which': [('WDT', 1.0)],
#   'popular': [('JJ', 1.0)],
#   'student': [('NN', 1.0)],
#   'times': [('NNS', 1.0)],
#   'spring/early': [('JJ', 1.0)],
#   'fruits': [('NNS', 1.0)],
#   'let': [('VB', 1.0)],
#   'arm': [('NN', 1.0)],
#   'engine': [('NN', 1.0)],
#   'Sitges': [('NNP', 1.0)],
#   'wondrous': [('JJ', 1.0)],
#   'Circuit-Festival-Barcelona': [('NN', 1.0)],
#   'resort': [('NN', 1.0)],
#   'early': [('JJ', 0.6), ('RB', 0.4)],
#   'raised': [('VBN', 1.0)],
#   'making': [('VBG', 1.0)],
#   'nasty': [('JJ', 1.0)],
#   'decorations': [('NNS', 1.0)],
#   'strain': [('NN', 1.0)],
#   '12am': [('CD', 1.0)],
#   'ways': [('NNS', 1.0)],
#   'beaten': [('NN', 1.0)],
#   "n't": [('RB', 1.0)],
#   'eventually': [('RB', 1.0)],
#   'legendary': [('JJ', 1.0)],
#   'sticks': [('NNS', 1.0)],
#   'just': [('RB', 1.0)],
#   'sunrise': [('NN', 1.0)],
#   'sensory': [('JJ', 1.0)],
#   'diablos': [('NN', 1.0)],
#   'every': [('DT', 1.0)],
#   'other': [('JJ', 1.0)],
#   'tabor': [('JJ', 1.0)],
#   'entirely': [('JJ', 1.0)],
#   'country': [('NN', 1.0)],
#   'eve': [('NN', 1.0)],
#   'together': [('RB', 1.0)],
#   'known': [('VBN', 1.0)],
#   'weeks': [('NNS', 1.0)],
#   'markets': [('NNS', 1.0)],
#   'bib': [('NN', 1.0)],
#   'Calcotada': [('NNP', 1.0)],
#   'ceremony': [('NN', 1.0)],
#   'sense': [('NN', 1.0)],
#   'heave': [('VBP', 1.0)],
#   'organize': [('VBP', 1.0)],
#   'pitchforks': [('NNS', 1.0)],
#   'Festival': [('NNP', 1.0)],
#   'becoming': [('VBG', 1.0)],
#   'run': [('NN', 0.3), ('VB', 0.3), ('VBN', 0.3)],
#   'because': [('IN', 1.0)],
#   '24-September': [('JJ', 1.0)],
#   'highlights': [('NNS', 1.0)],
#   'opinion': [('NN', 1.0)],
#   'called': [('VBN', 1.0)],
#   'seem': [('VB', 1.0)],
#   '11am': [('CD', 1.0)],
#   'Most': [('JJS', 1.0)],
#   'ca': [('MD', 1.0)],
#   'courage': [('NN', 1.0)],
#   'Jesus': [('NNP', 1.0)],
#   'holy-merce': [('JJ', 1.0)],
#   'community': [('NN', 1.0)],
#   'Don-Simon': [('JJ', 1.0)],
#   'summer': [('NN', 1.0)],
#   'Cathedral': [('NNP', 1.0)],
#   'lovers': [('NNS', 1.0)],
#   'glamorous': [('JJ', 1.0)],
#   'Sant-Joan': [('NNP', 1.0)],
#   'dragons': [('NNS', 1.0)],
#   'Easter': [('NNP', 1.0)],
#   'wind': [('NN', 1.0)],
#   'when': [('WRB', 1.0)],
#   'the-running-of-the-Bulls': [('NNS', 1.0)],
#   'parades': [('NNS', 1.0)],
#   'devil': [('NN', 1.0)],
#   'roaming': [('VBG', 1.0)],
#   'prejudice': [('NN', 1.0)],
#   'first': [('JJ', 1.0)],
#   'fine': [('JJ', 1.0)],
#   'competition': [('NN', 1.0)],
#   'potatoes': [('NNS', 1.0)],
#   'pride': [('NN', 1.0)],
#   'go': [('VB', 1.0)],
#   'battle': [('NN', 1.0)],
#   'ornaments': [('NNS', 1.0)],
#   'May': [('NNP', 1.0)],
#   'Caga-Tio': [('NNP', 1.0)],
#   'men': [('NNS', 1.0)],
#   'culture': [('NN', 1.0)],
#   'thing': [('NN', 1.0)],
#   'midsummer': [('NN', 1.0)],
#   'celebrate': [('NN', 1.0)],
#   '20kms': [('CD', 1.0)],
#   'messy': [('VBN', 1.0)],
#   'morning': [('NN', 1.0)],
#   'successful': [('JJ', 1.0)],
#   'Giant': [('NNP', 1.0)],
#   'weave': [('VBP', 1.0)],
#   'after': [('IN', 1.0)],
#   'outside': [('IN', 0.8), ('JJ', 0.2)],
#   'music': [('NN', 1.0)],
#   'who': [('WP', 1.0)],
#   'compared': [('VBN', 1.0)],
#   'eating': [('VBG', 1.0)],
#   'circles': [('NNS', 1.0)],
#   'end': [('NN', 0.5), ('VB', 0.5)],
#   'insane': [('JJ', 1.0)],
#   'castles': [('NNS', 1.0)],
#   'dressed': [('VBN', 1.0)],
#   'bangers': [('NNS', 1.0)],
#   'things': [('NNS', 1.0)],
#   'passing': [('NN', 1.0)],
#   'palm': [('NN', 1.0)],
#   'good': [('JJ', 1.0)],
#   'into': [('IN', 1.0)],
#   'breath': [('NN', 1.0)],
#   'giants': [('NNS', 1.0)],
#   'fun': [('VBP', 1.0)],
#   'hours': [('NNS', 1.0)],
#   'Plaza-Consistorial': [('NNP', 1.0)],
#   'peasant': [('NN', 1.0)],
#   'horse': [('NN', 1.0)],
#   'Laietana': [('NNP', 1.0)],
#   'being': [('VBG', 1.0)],
#   'aptly': [('RB', 1.0)],
#   'sparks': [('NNS', 1.0)],
#   'than': [('IN', 1.0)],
#   'City-Hall': [('NNP', 1.0)],
#   'very': [('RB', 1.0)],
#   'Sardana': [('NNP', 1.0)],
#   'beasts': [('VBZ', 1.0)],
#   'Mona': [('NNP', 1.0)],
#   'fire': [('NN', 1.0)],
#   'where': [('WRB', 1.0)],
#   'still': [('RB', 1.0)],
#   'beautifully': [('RB', 1.0)],
#   'most': [('JJS', 0.2), ('RBS', 0.8)],
#   'castanyada': [('NN', 1.0)],
#   'gentlemen': [('NNS', 1.0)],
#   'July': [('NNP', 1.0)],
#   'marked': [('VBN', 1.0)],
#   'symbol': [('NN', 1.0)],
#   'Festa-de-Sant-Medir': [('JJ', 1.0)],
#   'feed': [('VBD', 1.0)],
#   '40000': [('CD', 1.0)],
#   '23-April': [('JJ', 1.0)],
#   'sit': [('NN', 1.0)],
#   'commonly': [('RB', 1.0)],
#   'May/June': [('NNP', 1.0)],
#   'firework': [('NN', 1.0)],
#   'MIRA-Festival': [('JJ', 1.0)],
#   'post': [('NN', 1.0)],
#   'bagpipes': [('VBZ', 1.0)],
#   'plenty': [('NN', 1.0)],
#   'half': [('JJ', 0.5), ('NN', 0.5)],
#   'then': [('RB', 1.0)],
#   'thousands': [('NNS', 1.0)],
#   'chocolate': [('NN', 1.0)],
#   'ball-de-bastons': [('NNS', 1.0)],
#   'while': [('IN', 1.0)],
#   'January': [('NNP', 1.0)],
#   'mardis-gras': [('NN', 1.0)],
#   'edge': [('NN', 1.0)],
#   'amount': [('NN', 1.0)],
#   'fingers': [('NNS', 1.0)],
#   'Correfoc': [('NNP', 1.0)],
#   'flows': [('NNS', 1.0)],
#   'Armageddon': [('NNP', 1.0)],
#   'better': [('RB', 1.0)],
#   '10': [('CD', 1.0)],
#   'dancing': [('VBG', 1.0)],
#   'This': [('DT', 1.0)],
#   'clowns': [('NNS', 1.0)],
#   'Arrabassada': [('NNP', 1.0)],
#   'will': [('MD', 1.0)],
#   'buses': [('NNS', 1.0)],
#   'include': [('VBP', 1.0)],
#   'under': [('IN', 1.0)],
#   'biggie': [('JJ', 1.0)],
#   'sculptures': [('NNS', 1.0)],
#   'folk': [('NN', 1.0)],
#   'formation': [('NN', 1.0)],
#   'everyone': [('NN', 1.0)],
#   'books': [('NNS', 1.0)],
#   'easy': [('JJ', 1.0)],
#   'February': [('NNP', 1.0)],
#   'hold': [('VB', 1.0)],
#   'baptised': [('VBN', 1.0)],
#   'well': [('RB', 1.0)],
#   'reach': [('NN', 0.5), ('VB', 0.5)],
#   'was': [('VBD', 1.0)],
#   'stalls': [('NNS', 1.0)],
#   'Sep-2018': [('NNP', 1.0)],
#   'crowd': [('NN', 1.0)],
#   'so': [('IN', 1.0)],
#   'with': [('IN', 1.0)],
#   'patterns': [('NNS', 1.0)],
#   'English': [('NNP', 1.0)],
#   "All-Saints'Day": [('NNP', 1.0)],
#   'baby': [('NN', 1.0)],
#   'thrown': [('VBN', 1.0)],
#   'aftermath': [('NN', 1.0)],
#   'throws': [('VBZ', 1.0)],
#   'sundry': [('NNS', 1.0)],
#   'Chupinazo': [('NNP', 1.0)],
#   'arts': [('NNS', 1.0)],
#   'over': [('IN', 1.0)],
#   'firecrackers': [('NNS', 1.0)],
#   '2': [('CD', 1.0)],
#   'harvest': [('NN', 1.0)],
#   'tracks': [('NNS', 1.0)],
#   'Towers': [('NNP', 1.0)],
#   'about': [('IN', 1.0)],
#   'Tio-de-Nadal': [('NNP', 1.0)],
#   'bring': [('VB', 1.0)],
#   'setup': [('NN', 1.0)],
#   'street': [('NN', 1.0)],
#   'week': [('NN', 1.0)],
#   'elaborate': [('VBP', 1.0)],
#   'marzipan-based': [('JJ', 1.0)],
#   '15-August': [('JJ', 1.0)],
#   'wheel': [('NN', 1.0)],
#   'food': [('NN', 1.0)],
#   'March': [('NNP', 1.0)],
#   'infectious': [('JJ', 1.0)],
#   'second': [('JJ', 0.5), ('NN', 0.5)],
#   'sky': [('NN', 1.0)],
#   'followed': [('VBN', 1.0)],
#   'Saint-Sant-Medir': [('NNP', 1.0)],
#   'stripes': [('NNS', 1.0)],
#   'hitting': [('VBG', 1.0)],
#   'these': [('DT', 1.0)],
#   'slaying': [('VBG', 1.0)],
#   'grape': [('NN', 1.0)],
#   'traditional': [('JJ', 1.0)],
#   'obscene': [('JJ', 1.0)],
#   'fountain': [('VBP', 1.0)],
#   'three': [('CD', 1.0)],
#   'round': [('IN', 1.0)],
#   'funny': [('JJ', 1.0)],
#   'human': [('JJ', 1.0)],
#   '30': [('CD', 1.0)],
#   'aboard': [('IN', 1.0)],
#   'does': [('VBZ', 1.0)],
#   'main': [('JJ', 1.0)],
#   'takes': [('VBZ', 1.0)],
#   'represents': [('VBZ', 1.0)],
#   'showcase': [('NN', 1.0)],
#   'Wanderlust108': [('NNP', 1.0)],
#   'Such': [('JJ', 1.0)],
#   'ritual': [('JJ', 1.0)],
#   'needless': [('NN', 1.0)],
#   'length': [('NN', 1.0)],
#   'breathing': [('NN', 1.0)],
#   'people': [('NNS', 1.0)],
#   'wrapped': [('VBD', 1.0)],
#   'April': [('NNP', 1.0)],
#   'day': [('NN', 1.0)],
#   'only': [('RB', 1.0)],
#   'protector': [('NN', 1.0)],
#   'show': [('NN', 1.0)],
#   'famous': [('JJ', 1.0)],
#   'stellar': [('JJ', 1.0)],
#   'epic': [('JJ', 0.7), ('NN', 0.3)],
#   'treat': [('NN', 1.0)],
#   'red': [('JJ', 1.0)],
#   'man': [('NN', 1.0)],
#   'nightlife': [('IN', 1.0)],
#   'best': [('JJS', 0.8), ('RBS', 0.2)],
#   'circle': [('NN', 1.0)],
#   'figures': [('NNS', 1.0)],
#   'dips': [('NNS', 1.0)],
#   'Carnival': [('NNP', 1.0)],
#   'Sant-Jordi-Saint-George': [('JJ', 0.5), ('NN', 0.5)],
#   'pipes': [('NNS', 1.0)],
#   'dress': [('NN', 1.0)],
#   'flower': [('NN', 1.0)],
#   'navigating': [('VBG', 1.0)],
#   'common': [('JJ', 1.0)],
#   'Montjuic': [('NNP', 1.0)],
#   'them': [('PRP', 1.0)],
#   'said': [('VBD', 1.0)],
#   'checks': [('NNS', 1.0)],
#   'feast': [('JJ', 0.5), ('VBD', 0.5)],
#   'fight': [('NN', 1.0)],
#   'important': [('JJ', 1.0)],
#   'arms': [('NNS', 1.0)],
#   'back': [('RB', 1.0)],
#   'swig-al-fresco': [('JJ', 1.0)],
#   'dubstep': [('NN', 1.0)],
#   'loosely': [('RB', 1.0)],
#   'special': [('JJ', 1.0)],
#   'flutter': [('NN', 1.0)],
#   'onions': [('NNS', 1.0)],
#   "'s": [('POS', 0.7), ('VBZ', 0.3)],
#   'out': [('IN', 0.2), ('RP', 0.8)],
#   'some': [('DT', 1.0)],
#   'attend': [('VB', 1.0)],
#   'imagine': [('VB', 1.0)],
#   'found': [('VBN', 1.0)],
#   'Catholic': [('JJ', 1.0)],
#   'bus': [('NN', 1.0)],
#   'him': [('PRP', 1.0)],
#   'each': [('DT', 1.0)],
#   'picture': [('NN', 1.0)],
#   'F1': [('NNP', 1.0)],
#   'statues': [('NNS', 1.0)],
#   'pinya': [('NN', 1.0)],
#   'mix': [('VBD', 1.0)],
#   'iconic': [('NN', 1.0)],
#   'aka': [('JJ', 1.0)],
#   'las-ramblas': [('JJ', 1.0)],
#   'without': [('IN', 1.0)],
#   'del': [('NN', 1.0)],
#   'places': [('NNS', 1.0)],
#   'standing': [('VBG', 1.0)],
#   'Christmas-Eve': [('NNP', 1.0)],
#   'mache': [('NN', 1.0)],
#   'shows': [('NNS', 1.0)],
#   'until': [('IN', 1.0)],
#   'featuring': [('VBG', 1.0)],
#   'friend': [('VBP', 1.0)],
#   'accompanied': [('JJ', 0.3), ('VBN', 0.7)],
#   'horns': [('NNS', 1.0)],
#   'sports': [('NNS', 1.0)],
#   'care': [('NN', 1.0)],
#   'hour': [('NN', 1.0)],
#   'night': [('NN', 1.0)],
#   'precise': [('JJ', 1.0)],
#   'old-port': [('NN', 1.0)],
#   'motorcar': [('NN', 1.0)],
#   'wears': [('VBZ', 1.0)],
#   'book': [('NN', 1.0)],
#   'overindulge': [('VB', 1.0)],
#   'Correfocs': [('NNP', 1.0)],
#   'grapes': [('NNS', 1.0)],
#   'fireworks': [('NNS', 0.9), ('VBZ', 0.1)],
#   'live': [('JJ', 1.0)],
#   'buy': [('VB', 1.0)],
#   'raise': [('NN', 1.0)],
#   'during': [('IN', 1.0)],
#   'views': [('NNS', 1.0)],
#   'nation': [('NN', 1.0)],
#   'singing': [('VBG', 1.0)],
#   'say': [('VB', 1.0)],
#   'built': [('VBN', 1.0)],
#   'quirky': [('JJ', 1.0)],
#   'Gracia': [('NNP', 1.0)],
#   'Spanish-Grand-Prix': [('NNP', 1.0)],
#   'la-Gran-Rua-de-Carneval': [('JJ', 1.0)],
#   'one': [('CD', 1.0)],
#   'hermitage': [('NN', 1.0)],
#   'might': [('MD', 1.0)],
#   'by': [('IN', 1.0)],
#   'more': [('JJR', 0.8), ('RBR', 0.2)],
#   'fest': [('NN', 1.0)],
#   'its': [('PRP$', 1.0)],
#   'for': [('IN', 1.0)],
#   'cerveza': [('NN', 1.0)],
#   'Immaculate-Conception': [('NNP', 1.0)],
#   'characters': [('NNS', 1.0)],
#   'vendors': [('NNS', 1.0)],
#   'rave': [('VB', 0.5), ('VBP', 0.5)],
#   "-Kings'-Day": [('NN', 1.0)],
#   'heading': [('VBG', 1.0)],
#   'Northern': [('NNP', 1.0)],
#   'warm': [('JJ', 1.0)],
#   'easily': [('RB', 1.0)],
#   'runs': [('VBZ', 1.0)],
#   'biggest': [('JJS', 1.0)],
#   'leave': [('VBP', 1.0)],
#   'Fiesta-de-Barceloneta': [('NN', 1.0)],
#   'devils': [('NNS', 1.0)],
#   'desert': [('NN', 1.0)],
#   'drinking': [('NN', 1.0)],
#   'crowds': [('NN', 1.0)],
#   'party': [('NN', 1.0)],
#   'world': [('NN', 1.0)],
#   'intertwined': [('JJ', 1.0)],
#   'lanterns': [('NNS', 1.0)],
#   'Bunol': [('NNP', 0.5), ('VB', 0.5)],
#   'Primavera-Sound-Festival': [('NN', 1.0)],
#   'turn': [('VBP', 1.0)],
#   'adorned': [('VBN', 1.0)],
#   'newspaper': [('NN', 1.0)],
#   'Sanfermines': [('NNS', 1.0)],
#   'empty': [('JJ', 1.0)],
#   '21-August': [('JJ', 1.0)],
#   'port': [('JJ', 0.5), ('NN', 0.5)],
#   'Miguel-Cervantes': [('NNP', 1.0)],
#   'normally': [('RB', 1.0)],
#   'carrer-de-san-salvador': [('NN', 1.0)],
#   'Day-of-the-book': [('NNP', 1.0)],
#   'ancient': [('JJ', 1.0)],
#   'teams': [('VBP', 1.0)],
#   'extensive': [('JJ', 1.0)],
#   'intensity': [('JJ', 1.0)],
#   'personified': [('VBN', 1.0)],
#   'rife': [('JJ', 1.0)],
#   'huge': [('JJ', 1.0)],
#   'kick': [('FW', 0.5), ('NN', 0.5)],
#   'floats': [('NNS', 1.0)],
#   'Barcelona': [('NNP', 1.0)],
#   'exchanging': [('VBG', 1.0)],
#   'dia-de-sant-jordi': [('JJ', 1.0)],
#   'a': [('DT', 1.0)],
#   'rolls': [('NNS', 1.0)],
#   'woodwork': [('VBP', 1.0)],
#   'kind': [('NN', 1.0)],
#   'popularity': [('NN', 1.0)],
#   'castells': [('NNS', 1.0)],
#   'except': [('IN', 1.0)],
#   'Padrinos': [('NNPS', 1.0)],
#   'carry': [('VBP', 1.0)],
#   'grand': [('JJ', 1.0)],
#   'get': [('VB', 1.0)],
#   "L'ou-com-balla": [('NNP', 1.0)],
#   'as': [('IN', 1.0)],
#   'equality': [('NN', 1.0)],
#   'and': [('CC', 1.0)],
#   'la-merce-festival': [('NN', 1.0)],
#   'offering': [('VBG', 1.0)],
#   'hrs': [('NNS', 1.0)],
#   '24': [('CD', 1.0)],
#   'flags': [('NNS', 1.0)],
#   'Valentine': [('NNP', 1.0)],
#   'human-towers': [('NNS', 1.0)],
#   'opportunity': [('NN', 1.0)],
#   'seconds': [('NNS', 1.0)],
#   'families': [('NNS', 1.0)],
#   'actually': [('RB', 1.0)],
#   '5th': [('JJ', 1.0)],
#   'region': [('NN', 1.0)],
#   'celebrations': [('NNS', 1.0)],
#   'camp': [('VB', 0.5), ('VBP', 0.5)],
#   'Potter': [('NNP', 1.0)],
#   'he': [('PRP', 1.0)],
#   'lower': [('JJR', 1.0)],
#   'la-Merce': [('NN', 1.0)],
#   'St-George-Sant-Jordi': [('NNP', 1.0)],
#   'paddock': [('NN', 1.0)],
#   'energy': [('NN', 1.0)],
#   'little': [('JJ', 1.0)],
#   'paella': [('JJ', 0.5), ('NN', 0.5)],
#   'become': [('VBN', 1.0)],
#   'Festa-Major-de-Gracia': [('JJ', 1.0)],
#   'smiling': [('VBG', 1.0)],
#   'made': [('VBN', 1.0)],
#   'near': [('IN', 1.0)],
#   'route': [('NN', 1.0)],
#   'Saturday': [('NNP', 1.0)],
#   'colles-castellers': [('NNS', 1.0)],
#   'ever': [('RB', 1.0)],
#   'La-Tomatina': [('NNP', 1.0)],
#   'life': [('NN', 1.0)],
#   'depending': [('NN', 1.0)],
#   'across': [('IN', 1.0)],
#   'action': [('NN', 1.0)],
#   'size': [('NN', 1.0)],
#   'campfires': [('NNS', 1.0)],
#   'different': [('JJ', 1.0)],
#   'air': [('NN', 1.0)],
#   'bulls': [('NNS', 1.0)],
#   'wood': [('NN', 1.0)],
#   'purchase': [('VB', 1.0)],
#   'holy-patron-of-Barcelona': [('NN', 1.0)],
#   'stroll': [('VBP', 1.0)],
#   'lining': [('VBG', 1.0)],
#   'but': [('CC', 1.0)],
#   'Spaniards': [('NNPS', 1.0)],
#   'taking': [('VBG', 1.0)],
#   'Spain': [('NNP', 1.0)],
#   'rows': [('NNS', 1.0)],
#   'beach': [('NN', 1.0)],
#   'Assumption-Day': [('NNP', 1.0)],
#   'beat': [('NN', 1.0)],
#   'base': [('NN', 1.0)],
#   'pack': [('NN', 1.0)],
#   'gift': [('NN', 1.0)],
#   'Maria': [('NNP', 1.0)],
#   'exchange': [('VBP', 1.0)],
#   'awake': [('VBP', 1.0)],
#   'sinfully': [('RB', 1.0)],
#   'part': [('NN', 1.0)],
#   'qualifiers': [('NNS', 1.0)],
#   'horses': [('NNS', 1.0)],
#   'calvacada': [('NN', 1.0)],
#   'wonderful': [('JJ', 1.0)],
#   'Harry': [('NNP', 1.0)],
#   'treats': [('NNS', 1.0)],
#   'Circuit-de-Catalunya': [('NNP', 1.0)],
#   'from': [('IN', 1.0)],
#   'riders': [('NNS', 1.0)],
#   'supposed': [('VBN', 1.0)],
#   'festivity': [('NN', 1.0)],
#   'hand': [('NN', 1.0)],
#   'countries': [('NNS', 1.0)],
#   'last': [('JJ', 1.0)],
#   'Port-Vell': [('NNP', 1.0)],
#   'off': [('RP', 1.0)],
#   'costumes': [('NNS', 1.0)],
#   'holiday': [('NN', 1.0)],
#   'meal': [('NN', 1.0)],
#   'countryside': [('NN', 1.0)],
#   'dances': [('VBZ', 1.0)],
#   'bars': [('NNS', 1.0)],
#   'water': [('NN', 1.0)],
#   'bonkers': [('NNS', 1.0)],
#   'cities': [('NNS', 1.0)],
#   'Epiphany': [('JJ', 0.7), ('NNP', 0.3)],
#   'on': [('IN', 1.0)],
#   'acrobats': [('NNS', 1.0)],
#   'Montmelo': [('NNP', 1.0)],
#   'Monegros-Desert-Festival': [('JJ', 1.0)],
#   'Nevada': [('NNP', 1.0)],
#   'Man': [('NNP', 1.0)],
#   'minutes': [('NNS', 1.0)],
#   'tightest': [('NN', 1.0)],
#   'days': [('NNS', 1.0)],
#   'The': [('DT', 1.0)],
#   '4:30pm': [('CD', 1.0)],
#   'roads': [('NNS', 1.0)],
#   'place': [('NN', 0.8), ('VBP', 0.2)],
#   'throughout': [('IN', 1.0)],
#   '6th-14th': [('JJ', 1.0)],
#   'hundreds': [('NNS', 1.0)],
#   '24th': [('CD', 1.0)],
#   'Ferraris': [('NNP', 1.0)],
#   'not': [('RB', 1.0)],
#   'in': [('IN', 1.0)],
#   'hedonists': [('NNS', 1.0)],
#   'next': [('JJ', 1.0)],
#   'Deda-de-los-Reyes-Magos': [('JJ', 1.0)],
#   'replete': [('VBP', 1.0)],
#   'venue': [('NN', 1.0)],
#   'Formula-One-Spanish-Grand-Prix': [('NNP', 1.0)],
#   'woman': [('NN', 1.0)],
#   'genre': [('NN', 1.0)],
#   'sometimes': [('RB', 0.5), ('VBZ', 0.5)],
#   'Catalonia': [('NNP', 1.0)],
#   'pop': [('VB', 1.0)],
#   'elves': [('NNS', 1.0)],
#   'what': [('WP', 1.0)],
#   'thirsty': [('JJ', 1.0)],
#   'band': [('NN', 1.0)],
#   'lesbian': [('JJ', 1.0)],
#   'between': [('IN', 1.0)],
#   "'re": [('VBP', 1.0)],
#   'abundance': [('NN', 1.0)],
#   'endless': [('JJ', 1.0)],
#   'canons': [('NNS', 1.0)],
#   'fancy': [('JJ', 1.0)],
#   'attracting': [('VBG', 1.0)],
#   'four': [('CD', 1.0)],
#   'nicknamed': [('VBD', 1.0)],
#   'celebration': [('NN', 1.0)],
#   'their': [('PRP$', 1.0)],
#   'means': [('VBZ', 1.0)],
#   'entertainment': [('NN', 1.0)],
#   'throw': [('VBP', 1.0)],
#   'bass': [('NN', 1.0)],
#   'Ferris': [('NNP', 1.0)],
#   'Sunday': [('NNP', 1.0)],
#   'Corpus-Christi': [('NN', 1.0)],
#   'gives': [('VBZ', 1.0)],
#   'benicassim': [('NN', 1.0)],
#   'race': [('NN', 1.0)],
#   'swathes': [('NNS', 1.0)],
#   '23rd/24th': [('CD', 1.0)],
#   'mostly': [('RB', 1.0)],
#   'Greocia': [('NNP', 1.0)],
#   'the': [('DT', 1.0)],
#   'represent': [('VB', 0.5), ('VBP', 0.5)],
#   'Colles': [('NNP', 1.0)],
#   'walk': [('VBP', 1.0)],
#   'big': [('JJ', 1.0)],
#   'picnic': [('NN', 1.0)],
#   'rockets': [('NNS', 1.0)],
#   'see': [('VB', 1.0)],
#   'indie': [('NN', 1.0)],
#   'it': [('PRP', 1.0)],
#   'Sonar': [('NNP', 1.0)],
#   'Jun-2018': [('NNP', 1.0)],
#   'busy': [('JJ', 1.0)],
#   'stall': [('PDT', 1.0)],
#   "del'Argentera-Via": [('JJ', 1.0)],
#   'long': [('JJ', 0.5), ('RB', 0.5)],
#   'papier': [('JJR', 0.5), ('NN', 0.5)],
#   '4': [('CD', 1.0)],
#   'paused': [('VBN', 1.0)],
#   'thanks': [('NNS', 1.0)],
#   'parc-de-la-ciutadella': [('NN', 1.0)],
#   'died': [('VBD', 1.0)],
#   'series': [('NN', 1.0)],
#   'Valencia': [('NNP', 1.0)],
#   'tower': [('NN', 1.0)],
#   'accessible': [('JJ', 1.0)],
#   'precarious': [('JJ', 1.0)],
#   'festival': [('JJ', 0.0), ('NN', 0.9), ('VBD', 0.0)],
#   'road': [('NN', 1.0)],
#   'around': [('IN', 0.7), ('RP', 0.3)],
#   'sant-joan': [('JJ', 1.0)],
#   'order': [('NN', 1.0)],
#   'at': [('IN', 1.0)],
#   'parties': [('NNS', 1.0)],
#   'drummers': [('NNS', 1.0)],
#   'cartons': [('NNS', 1.0)],
#   'sant-juan/st-john': [('JJ', 1.0)],
#   'gobble': [('VB', 1.0)],
#   'Holy-Sant-Joan': [('NNP', 1.0)],
#   'Catalan': [('NNP', 1.0)],
#   'reception': [('NN', 1.0)],
#   'classic': [('JJ', 1.0)],
#   'stick': [('JJ', 0.5), ('NN', 0.5)],
#   'do': [('VBP', 1.0)],
#   'fire-crackers': [('NNS', 1.0)],
#   'pooped': [('VBN', 1.0)],
#   'artists': [('NNS', 1.0)],
#   'BCN': [('NNP', 1.0)],
#   'month': [('NN', 1.0)],
#   'like': [('IN', 0.8), ('JJ', 0.2)],
#   'June': [('NNP', 1.0)],
#   'idyllic': [('JJ', 1.0)],
#   'exhausting': [('VBG', 1.0)],
#   'championing': [('NN', 1.0)],
#   'spewing': [('VBG', 1.0)],
#   'drive': [('VBP', 1.0)],
#   'poo': [('VB', 1.0)],
#   '6-January': [('JJ', 1.0)],
#   'child': [('NN', 1.0)],
#   'couples': [('NNS', 1.0)],
#   'citywide': [('JJ', 1.0)],
#   'orange': [('VBP', 1.0)],
#   'Sant-Medir': [('NNP', 1.0)],
#   'fountains': [('NNS', 1.0)],
#   'dish': [('VBP', 1.0)],
#   'shell': [('NN', 1.0)],
#   'older': [('JJR', 1.0)],
#   'top': [('JJ', 0.5), ('NN', 0.5)],
#   'give': [('VBP', 1.0)],
#   'impressive': [('JJ', 1.0)],
#   'historical': [('JJ', 1.0)],
#   'depends': [('VBZ', 1.0)],
#   'did': [('VBD', 1.0)],
#   'Gay': [('NNP', 1.0)],
#   'Caga-tio': [('NNP', 1.0)],
#   'through': [('IN', 1.0)],
#   'less': [('RBR', 1.0)],
#   'racetrack': [('NN', 1.0)],
#   'In': [('IN', 1.0)],
#   'such': [('JJ', 1.0)],
#   '23-June': [('JJ', 1.0)],
#   'running': [('VBG', 1.0)],
#   'carnival': [('NN', 0.8), ('VBP', 0.2)],
#   'must': [('MD', 1.0)],
#   'various': [('JJ', 1.0)],
#   'public': [('JJ', 1.0)],
#   'late': [('JJ', 1.0)],
#   'alternative': [('JJ', 1.0)],
#   'move': [('NN', 1.0)],
#   'montmelo': [('NN', 1.0)],
#   'rose': [('VBD', 1.0)],
#   'small': [('JJ', 1.0)],
#   'santa-euleolia': [('JJ', 1.0)],
#   'egg': [('NN', 1.0)],
#   'behaviour': [('VBP', 1.0)],
#   'typically': [('RB', 1.0)],
#   'dinner': [('NN', 1.0)],
#   'Burning': [('NNP', 1.0)],
#   'patron': [('NN', 1.0)],
#   'nearby': [('JJ', 1.0)],
#   '.': [('.', 1.0)],
#   'flamenco': [('NN', 1.0)],
#   'techno': [('NN', 1.0)],
#   'successfully': [('RB', 1.0)],
#   'candies': [('NNS', 1.0)],
#   'debauchery': [('NN', 1.0)],
#   'Catalans': [('NNPS', 1.0)],
#   '50000': [('CD', 1.0)],
#   'news': [('NN', 1.0)],
#   'striking': [('JJ', 1.0)],
#   'preserved': [('VBD', 1.0)],
#   '24-Sep': [('JJ', 1.0)],
#   'children': [('NNS', 1.0)],
#   'greater': [('JJR', 1.0)],
#   'should': [('MD', 1.0)],
#   'animals': [('NNS', 1.0)],
#   'drums': [('VB', 1.0)],
#   'soda': [('NN', 1.0)],
#   'Primavera': [('NNP', 1.0)],
#   'gran-de-greocia': [('NN', 1.0)],
#   'her': [('PRP$', 1.0)],
#   'gay': [('NN', 1.0)],
#   'extravagantly': [('RB', 1.0)],
#   'Criola-Beach-Festival': [('JJ', 1.0)],
#   'visitors': [('NNS', 1.0)],
#   'his': [('PRP$', 1.0)],
#   'explodes': [('VBZ', 1.0)],
#   'gifts': [('JJ', 0.2), ('NNS', 0.8)],
#   'Gegants': [('NNP', 1.0)],
#   'seen': [('VBN', 1.0)],
#   'colourful': [('JJ', 1.0)],
#   'hat': [('NN', 1.0)],
#   'tradition': [('NN', 1.0)],
#   'gets': [('VBZ', 1.0)],
#   'acts': [('NNS', 0.5), ('VBZ', 0.5)],
#   'mayhem': [('JJ', 1.0)],
#   'opening': [('NN', 1.0)],
#   'highlight': [('VBD', 1.0)],
#   'poet': [('NN', 1.0)],
#   'twist': [('NN', 1.0)],
#   'time': [('NN', 1.0)],
#   'millions': [('NNS', 1.0)],
#   'Plaza-Rius-i-Taulet': [('NNP', 1.0)],
#   'unity': [('NN', 1.0)],
#   'involves': [('VBZ', 1.0)],
#   'style': [('NN', 1.0)],
#   'event': [('NN', 1.0)],
#   'fairs': [('NNS', 1.0)],
#   'dispatch': [('VB', 1.0)],
#   'Sound': [('NNP', 1.0)],
#   'rock': [('NN', 1.0)],
#   'pre-parties': [('JJ', 1.0)],
#   'Benicassim': [('NNP', 1.0)],
#   'has': [('VBZ', 1.0)],
#   'electronic': [('JJ', 1.0)],
#   'car': [('NN', 1.0)],
#   'balloons': [('NNS', 1.0)],
#   'name': [('VBP', 1.0)],
#   'date': [('NN', 1.0)],
#   'worth': [('IN', 1.0)],
#   'Lesbian': [('NNP', 1.0)],
#   '8-Dec': [('CD', 1.0)],
#   'brought': [('NN', 1.0)],
#   'gallivant': [('VB', 1.0)],
#   'galore': [('VBP', 1.0)],
#   'taxi': [('VB', 1.0)],
#   'centre': [('NN', 1.0)],
#   'twelve': [('JJ', 0.7), ('NN', 0.3)],
#   'months': [('NNS', 1.0)],
#   'below': [('RB', 1.0)],
#   'also': [('RB', 1.0)],
#   'dainty': [('NN', 1.0)],
#   'talked': [('VBN', 1.0)],
#   'selling': [('VBG', 1.0)],
#   'tents': [('NNS', 1.0)],
#   'leafs': [('NN', 1.0)],
#   'Mardi-Gras': [('NNP', 1.0)],
#   'quickly': [('RB', 1.0)],
#   'that': [('IN', 0.5), ('WDT', 0.5)],
#   'sweet': [('JJ', 1.0)],
#   'incarnations': [('NNS', 1.0)],
#   'fuel': [('NN', 1.0)],
#   'join': [('VBP', 1.0)],
#   'acting': [('VBG', 1.0)],
#   'spring': [('NN', 1.0)],
#   'Formula-One': [('NN', 1.0)],
#   'right': [('JJ', 1.0)],
#   'upon': [('RP', 1.0)],
#   'encourage': [('VB', 1.0)],
#   'wise': [('NN', 1.0)],
#   'fire-runs': [('VBZ', 1.0)],
#   'Traditionally': [('RB', 1.0)],
#   'granny': [('NN', 1.0)],
#   'crowded': [('JJ', 1.0)],
#   'log': [('NN', 1.0)],
#   'white': [('JJ', 1.0)],
#   'differences': [('NNS', 1.0)],
#   'talking': [('VBG', 1.0)],
#   'Cruilla-Festival': [('NN', 1.0)],
#   'spurt': [('NN', 1.0)],
#   'Cervantes': [('NNP', 1.0)],
#   'Spanish': [('JJ', 1.0)],
#   'goers': [('NNS', 1.0)],
#   'turns': [('NNS', 1.0)],
#   'sangria': [('NN', 0.7), ('NNS', 0.3)],
#   'up': [('RB', 0.2), ('RP', 0.8)],
#   'correfoc': [('NN', 1.0)],
#   'cafes': [('NNS', 1.0)],
#   'wild': [('JJ', 1.0)],
#   'young': [('JJ', 1.0)],
#   'equivalent': [('NN', 1.0)],
#   'any': [('DT', 1.0)],
#   'light': [('JJ', 1.0)],
#   'entire': [('JJ', 1.0)],
#   'individual': [('JJ', 1.0)],
#   'kings': [('NNS', 1.0)],
#   'drum': [('NN', 1.0)],
#   'celebrates': [('VBZ', 1.0)],
#   'evil': [('JJ', 1.0)],
#   'make': [('VBP', 1.0)],
#   'of': [('IN', 1.0)],
#   'occasionally': [('RB', 1.0)],
#   'attendees': [('NNS', 1.0)],
#   'dubbed': [('VB', 1.0)],
#   'decorated': [('JJ', 0.2), ('VBD', 0.2), ('VBN', 0.6)],
#   'have': [('VB', 1.0)],
#   'all': [('DT', 0.9), ('PDT', 0.1)],
#   'Starting': [('VBG', 1.0)],
#   'Often': [('RB', 1.0)],
#   'balance': [('NN', 1.0)],
#   'begins': [('VBZ', 1.0)],
#   'theaters': [('NNS', 1.0)],
#   '23rd': [('CD', 1.0)],
#   'two': [('CD', 1.0)],
#   'culmination': [('NN', 1.0)],
#   'famed': [('VBN', 1.0)],
#   'exhilarating': [('VBG', 1.0)],
#   'growing': [('VBG', 1.0)],
#   'company': [('NN', 1.0)],
#   'can': [('MD', 1.0)],
#   'believe': [('VB', 1.0)],
#   'celebrated': [('VBD', 0.3), ('VBN', 0.7)],
#   'everywhere': [('RB', 1.0)],
#   'planet': [('NN', 1.0)],
#   'be': [('VB', 1.0)],
#   'Sant': [('NNP', 1.0)],
#   'strength': [('NN', 1.0)],
#   'before': [('IN', 0.5), ('RB', 0.5)],
#   'lined': [('VBN', 1.0)],
#   'pretty': [('JJ', 1.0)],
#   'luck': [('NN', 1.0)],
#   'festivals': [('NNS', 1.0)],
#   'stage': [('NN', 1.0)],
#   'take': [('VB', 0.5), ('VBP', 0.5)],
#   'broadest': [('JJS', 1.0)],
#   'Benicassim-International-festival-FIB': [('NNP', 1.0)],
#   'lizard': [('NN', 1.0)],
#   'mountain': [('NN', 1.0)],
#   'roasting': [('VBG', 1.0)],
#   'expect': [('NN', 0.2), ('VB', 0.6), ('VBP', 0.2)],
#   'ship': [('NN', 1.0)],
#   'blanket': [('NN', 1.0)],
#   'abstinence': [('NN', 1.0)],
#   'chance': [('NN', 1.0)],
#   'dishes': [('NNS', 1.0)],
#   'great': [('JJ', 1.0)],
#   'climes': [('NNS', 1.0)],
#   'shortest': [('JJS', 1.0)],
#   'steps': [('NNS', 1.0)],
#   'occasion': [('NN', 1.0)],
#   'hard': [('JJ', 1.0)],
#   'ride': [('VBP', 1.0)],
#   'becomes': [('NNS', 0.3), ('VBZ', 0.7)],
#   'song': [('NN', 1.0)],
#   '1-Nov': [('CD', 1.0)],
#   'inventive': [('JJ', 1.0)],
#   'yourself': [('PRP', 1.0)],
#   'costliest': [('JJS', 1.0)],
#   'kids': [('NNS', 1.0)],
#   'sing': [('VBG', 1.0)],
#   'meets': [('NNS', 1.0)],
#   'castellers': [('NNS', 1.0)],
#   'Montjuic-de-Nit': [('NNP', 1.0)],
#   'area': [('NN', 1.0)],
#   'concerts': [('NNS', 0.7), ('VBZ', 0.3)],
#   'face': [('NN', 1.0)],
#   'free': [('JJ', 1.0)],
#   'de': [('FW', 1.0)],
#   '22': [('CD', 1.0)],
#   'Candy-Festival': [('JJ', 1.0)],
#   'wants': [('VBZ', 1.0)],
#   'beautiful': [('JJ', 1.0)],
#   'dead': [('JJ', 1.0)],
#   'new': [('JJ', 1.0)],
#   'swing': [('NN', 1.0)],
#   'handheld': [('NN', 1.0)],
#   'roses': [('NNS', 0.7), ('VBZ', 0.3)],
#   'is': [('VBZ', 1.0)],
#   'extends': [('NNS', 1.0)],
#   'Saint': [('NNP', 1.0)],
#   'appeal': [('NN', 1.0)],
#   'districts': [('NNS', 1.0)],
#   'journey': [('NN', 1.0)],
#   'perform': [('VBP', 1.0)],
#   'idea': [('NN', 1.0)],
#   'flowers': [('NNS', 1.0)],
#   'international': [('JJ', 1.0)],
#   'year': [('NN', 1.0)],
#   'are': [('VBP', 1.0)],
#   'showcasing': [('VBG', 1.0)],
#   'bean': [('NN', 1.0)],
#   'set': [('VBD', 0.3), ('VBN', 0.3), ('VBP', 0.3)],
#   'several': [('JJ', 1.0)],
#   'La-Merc': [('JJ', 1.0)],
#   'automobile': [('NN', 1.0)],
#   'push': [('NN', 1.0)],
#   'along': [('IN', 1.0)],
#   'calimocho': [('NN', 1.0)],
#   'sweets': [('NNS', 1.0)],
#   'completely': [('RB', 1.0)],
#   'fiesta': [('JJ', 0.5), ('NN', 0.5)],
#   'meant': [('VBN', 1.0)],
#   'Reis': [('NNP', 1.0)],
#   'panellets': [('NNS', 1.0)],
#   'staple': [('NN', 1.0)],
#   'train': [('NN', 1.0)],
#   'boat': [('NN', 1.0)],
#   'picturesque': [('NN', 1.0)],
#   'official': [('JJ', 1.0)],
#   'fashionable': [('JJ', 1.0)],
#   'giant': [('JJ', 0.3), ('NN', 0.7)],
#   'godparents': [('NNS', 1.0)],
#   'girls': [('NNS', 1.0)],
#   'chestnuts': [('NNS', 1.0)],
#   'Bethlehem': [('NNP', 1.0)],
#   'held': [('VBN', 1.0)],
#   'sorts': [('NNS', 1.0)],
#   'Catalan-folk': [('JJ', 1.0)],
#   'weeklong': [('JJ', 1.0)],
#   'form': [('VBP', 1.0)],
#   'or': [('CC', 1.0)],
#   'bard': [('NN', 1.0)],
#   'completed': [('VBN', 1.0)],
#   'era': [('NN', 1.0)],
#   'culinary': [('JJ', 1.0)],
#   'district': [('NN', 1.0)],
#   'procession': [('NN', 1.0)],
#   'creations': [('NNS', 1.0)],
#   'saint': [('NN', 1.0)],
#   'compete': [('NN', 1.0)],
#   'evenings': [('NNS', 1.0)],
#   'fruity': [('NN', 1.0)],
#   'destination': [('NN', 1.0)],
#   'electo': [('JJ', 1.0)],
#   '-': [(':', 1.0)],
#   'Joan': [('NNP', 1.0)],
#   'August': [('NNP', 1.0)],
#   'many': [('JJ', 1.0)],
#   'prizes': [('NNS', 1.0)],
#   'partying': [('VBG', 1.0)],
#   'On': [('IN', 1.0)],
#   'Palace-of-the-Generals': [('NNS', 1.0)],
#   'concert': [('JJ', 1.0)],
#   'poo-log': [('NN', 1.0)],
#   'clashing': [('VBG', 1.0)],
#   'Castellers': [('NNPS', 1.0)],
#   'carrer-de-marques': [('NNS', 1.0)],
#   'dancers': [('NNS', 1.0)],
#   'September': [('NNP', 1.0)],
#   'Parc-del-Forum': [('NNP', 1.0)],
#   'sharp': [('JJ', 1.0)],
#   'heads': [('NNS', 1.0)],
#   'full': [('JJ', 1.0)],
#   'Monegros': [('NNP', 1.0)],
#   'Fiesta-de-la-Merce': [('NN', 1.0)],
#   'even': [('RB', 1.0)],
#   'colorful': [('JJ', 1.0)],
#   'forty': [('JJ', 1.0)],
#   'entrance': [('NN', 1.0)],
#   'fire-run': [('JJ', 1.0)],
#   'town': [('NN', 1.0)],
#   'nonstop': [('JJ', 1.0)],
#   'arrival': [('NN', 1.0)],
#   'La-Merce': [('NN', 1.0)],
#   'Feria-de-abril': [('NNP', 1.0)],
#   'Fiesta-del-barrio': [('NNP', 1.0)],
#   'population': [('NN', 1.0)],
#   'Oct-2018': [('NNP', 1.0)],
#   'to': [('TO', 1.0)],
#   'ages': [('NNS', 1.0)],
#   'enjoy': [('VB', 1.0)],
#   'venues': [('NNS', 1.0)],
#   'oak': [('NN', 1.0)],
#   'saw': [('VBD', 1.0)],
#   'eggs': [('NNS', 1.0)],
#   'been': [('VBN', 1.0)],
#   'major': [('JJ', 1.0)],
#   'headscarf': [('NN', 1.0)],
#   'Halloween': [('NNP', 1.0)],
#   'trumpet': [('NN', 1.0)],
#   'roars': [('VBZ', 1.0)],
#   'single': [('JJ', 1.0)],
#   'drivers': [('NNS', 1.0)],
#   'attracts': [('VBZ', 1.0)],
#   'odd': [('JJ', 1.0)],
#   'clubs': [('NNS', 1.0)],
#   'flag': [('VBZ', 1.0)],
#   'usually': [('RB', 1.0)],
#   'eat': [('VBP', 1.0)],
#   'you': [('PRP', 1.0)],
#   'mustard': [('VBP', 1.0)],
#   'traditions': [('NNS', 1.0)],
#   'dates': [('NNS', 1.0)],
#   '5th/6th': [('CD', 1.0)],
#   'celebrating': [('VBG', 1.0)],
#   'pyrotechnics': [('NNS', 1.0)],
#   ...},
#  {'.': [('CD', 0.0),
#    ('DT', 0.2),
#    ('IN', 0.1),
#    ('JJ', 0.2),
#    ('JJS', 0.0),
#    ('NN', 0.2),
#    ('NNP', 0.2),
#    ('NNS', 0.0),
#    ('RB', 0.1),
#    ('VBG', 0.0)],
#   ':': [('CD', 0.5), ('DT', 0.5)],
#   'CC': [('CD', 0.0),
#    ('DT', 0.1),
#    ('IN', 0.1),
#    ('JJ', 0.1),
#    ('JJR', 0.0),
#    ('NN', 0.2),
#    ('NNP', 0.0),
#    ('NNPS', 0.0),
#    ('NNS', 0.2),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RB', 0.0),
#    ('VB', 0.1),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.0),
#    ('VBZ', 0.0)],
#   'CD': [('CC', 0.0),
#    ('DT', 0.0),
#    ('IN', 0.2),
#    ('JJ', 0.0),
#    ('NN', 0.2),
#    ('NNP', 0.1),
#    ('NNS', 0.3),
#    ('RB', 0.0),
#    ('TO', 0.0),
#    ('VBZ', 0.0)],
#   'DT': [('CC', 0.0),
#    ('CD', 0.0),
#    ('IN', 0.0),
#    ('JJ', 0.2),
#    ('JJR', 0.0),
#    ('JJS', 0.0),
#    ('MD', 0.0),
#    ('NN', 0.5),
#    ('NNP', 0.1),
#    ('NNPS', 0.0),
#    ('NNS', 0.1),
#    ('RB', 0.0),
#    ('RBS', 0.0),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.0),
#    ('VBZ', 0.0)],
#   'FW': [('NN', 0.5), ('RP', 0.5)],
#   'IN': [('.', 0.0),
#    ('CC', 0.0),
#    ('CD', 0.0),
#    ('DT', 0.4),
#    ('FW', 0.0),
#    ('IN', 0.0),
#    ('JJ', 0.1),
#    ('JJR', 0.0),
#    ('JJS', 0.0),
#    ('NN', 0.1),
#    ('NNP', 0.2),
#    ('NNS', 0.1),
#    ('PDT', 0.0),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RB', 0.0),
#    ('TO', 0.0),
#    ('VBG', 0.0),
#    ('WDT', 0.0)],
#   'JJ': [('.', 0.0),
#    ('CC', 0.0),
#    ('CD', 0.0),
#    ('DT', 0.0),
#    ('IN', 0.1),
#    ('JJ', 0.1),
#    ('JJR', 0.0),
#    ('NN', 0.4),
#    ('NNP', 0.1),
#    ('NNS', 0.2),
#    ('RB', 0.0),
#    ('RBS', 0.0),
#    ('TO', 0.0),
#    ('VBG', 0.0),
#    ('VBZ', 0.0),
#    ('WRB', 0.0)],
#   'JJR': [('.', 0.1),
#    ('IN', 0.4),
#    ('JJ', 0.1),
#    ('NN', 0.1),
#    ('NNS', 0.3),
#    ('RB', 0.1)],
#   'JJS': [('JJ', 0.2),
#    ('NN', 0.4),
#    ('NNP', 0.0),
#    ('NNS', 0.2),
#    ('RBS', 0.0),
#    ('VBN', 0.0),
#    ('VBP', 0.0)],
#   'MD': [('RB', 0.3), ('VB', 0.7)],
#   'NN': [('.', 0.1),
#    (':', 0.0),
#    ('CC', 0.1),
#    ('CD', 0.0),
#    ('DT', 0.0),
#    ('IN', 0.3),
#    ('JJ', 0.0),
#    ('JJR', 0.0),
#    ('JJS', 0.0),
#    ('MD', 0.0),
#    ('NN', 0.1),
#    ('NNP', 0.0),
#    ('NNS', 0.1),
#    ('PDT', 0.0),
#    ('POS', 0.0),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RB', 0.0),
#    ('RBS', 0.0),
#    ('RP', 0.0),
#    ('TO', 0.0),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.0),
#    ('VBP', 0.0),
#    ('VBZ', 0.1),
#    ('WDT', 0.0),
#    ('WRB', 0.0)],
#   'NNP': [('.', 0.1),
#    ('CC', 0.1),
#    ('CD', 0.0),
#    ('DT', 0.1),
#    ('FW', 0.0),
#    ('IN', 0.2),
#    ('JJ', 0.0),
#    ('JJS', 0.0),
#    ('NN', 0.1),
#    ('NNP', 0.1),
#    ('NNPS', 0.0),
#    ('NNS', 0.1),
#    ('POS', 0.0),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RB', 0.0),
#    ('RBS', 0.0),
#    ('TO', 0.0),
#    ('VB', 0.0),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBP', 0.0),
#    ('VBZ', 0.1),
#    ('WDT', 0.0),
#    ('WRB', 0.0)],
#   'NNPS': [('CC', 0.5), ('NNS', 0.2), ('VBP', 0.2)],
#   'NNS': [('.', 0.0),
#    (':', 0.0),
#    ('CC', 0.1),
#    ('DT', 0.0),
#    ('IN', 0.3),
#    ('JJ', 0.0),
#    ('JJR', 0.0),
#    ('MD', 0.0),
#    ('NN', 0.0),
#    ('NNP', 0.0),
#    ('NNS', 0.1),
#    ('PRP', 0.0),
#    ('RB', 0.0),
#    ('RP', 0.0),
#    ('TO', 0.0),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.0),
#    ('VBP', 0.2),
#    ('VBZ', 0.0),
#    ('WDT', 0.0),
#    ('WRB', 0.0)],
#   'PDT': [('DT', 1.0)],
#   'POS': [('JJ', 0.2), ('JJS', 0.2), ('NN', 0.5), ('NNS', 0.1)],
#   'PRP': [('DT', 0.1),
#    ('IN', 0.1),
#    ('MD', 0.1),
#    ('RP', 0.0),
#    ('TO', 0.1),
#    ('VB', 0.1),
#    ('VBD', 0.1),
#    ('VBP', 0.2),
#    ('VBZ', 0.3)],
#   'PRP$': [('JJ', 0.1), ('NN', 0.5), ('NNS', 0.3), ('VBN', 0.1)],
#   'RB': [('CC', 0.0),
#    ('CD', 0.0),
#    ('DT', 0.1),
#    ('IN', 0.2),
#    ('JJ', 0.1),
#    ('JJS', 0.0),
#    ('NN', 0.0),
#    ('NNP', 0.0),
#    ('NNS', 0.0),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RB', 0.1),
#    ('RBR', 0.0),
#    ('TO', 0.0),
#    ('VB', 0.1),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.1),
#    ('VBP', 0.0),
#    ('VBZ', 0.0)],
#   'RBR': [('JJ', 1.0)],
#   'RBS': [('JJ', 0.8), ('NN', 0.1), ('RB', 0.1)],
#   'RP': [('.', 0.0),
#    ('CC', 0.0),
#    ('CD', 0.1),
#    ('DT', 0.2),
#    ('IN', 0.3),
#    ('NN', 0.0),
#    ('NNS', 0.1),
#    ('PRP$', 0.0),
#    ('RB', 0.1),
#    ('TO', 0.0),
#    ('VBN', 0.0)],
#   'TO': [('DT', 0.2), ('JJ', 0.0), ('NN', 0.0), ('NNP', 0.1), ('VB', 0.6)],
#   'VB': [('.', 0.0),
#    ('CC', 0.0),
#    ('CD', 0.0),
#    ('DT', 0.2),
#    ('IN', 0.1),
#    ('JJ', 0.0),
#    ('NN', 0.1),
#    ('NNS', 0.0),
#    ('PRP', 0.1),
#    ('RB', 0.0),
#    ('RP', 0.1),
#    ('TO', 0.1),
#    ('VBG', 0.0),
#    ('VBN', 0.1),
#    ('VBZ', 0.0),
#    ('WP', 0.1)],
#   'VBD': [('CC', 0.0),
#    ('DT', 0.2),
#    ('IN', 0.3),
#    ('NNS', 0.0),
#    ('PRP', 0.2),
#    ('RP', 0.0),
#    ('TO', 0.0),
#    ('VBN', 0.1),
#    ('VBP', 0.0)],
#   'VBG': [('CC', 0.1),
#    ('CD', 0.0),
#    ('DT', 0.2),
#    ('IN', 0.2),
#    ('JJ', 0.1),
#    ('JJR', 0.1),
#    ('NN', 0.1),
#    ('NNP', 0.0),
#    ('NNS', 0.1),
#    ('RB', 0.0),
#    ('RP', 0.1)],
#   'VBN': [('CC', 0.0),
#    ('DT', 0.1),
#    ('IN', 0.6),
#    ('JJ', 0.0),
#    ('NN', 0.0),
#    ('NNS', 0.1),
#    ('RB', 0.0),
#    ('RP', 0.1),
#    ('TO', 0.1),
#    ('VBN', 0.0)],
#   'VBP': [('DT', 0.2),
#    ('IN', 0.2),
#    ('JJ', 0.1),
#    ('NN', 0.1),
#    ('NNP', 0.0),
#    ('NNS', 0.1),
#    ('PRP', 0.0),
#    ('PRP$', 0.0),
#    ('RP', 0.1),
#    ('TO', 0.0),
#    ('VBD', 0.0),
#    ('VBG', 0.0),
#    ('VBN', 0.1),
#    ('VBZ', 0.0)],
#   'VBZ': [('DT', 0.4),
#    ('IN', 0.1),
#    ('JJ', 0.1),
#    ('NN', 0.1),
#    ('NNP', 0.0),
#    ('NNS', 0.0),
#    ('PRP', 0.0),
#    ('RB', 0.1),
#    ('RBR', 0.0),
#    ('VBN', 0.1),
#    ('VBP', 0.0)],
#   'WDT': [('DT', 0.2), ('VBP', 0.2), ('VBZ', 0.6)],
#   'WP': [('MD', 0.3), ('PRP$', 0.3), ('VBZ', 0.3)],
#   'WRB': [('DT', 0.3), ('JJ', 0.2), ('NNS', 0.5)]},
#  ['Epiphany',
#   '5th/6th',
#   'January',
#   'Spaniards',
#   'and',
#   'Catalans',
#   'exchange',
#   'gifts',
#   'Christmas',
#   'style',
#   'the',
#   'eve',
#   'of',
#   'the',
#   'Epiphany',
#   'the',
#   '5th',
#   'January',
#   'is',
#   'marked',
#   'by',
#   'the',
#   'arrival',
#   'of',
#   'the',
#   'wise',
#   'men',
#   'by',
#   'boat',
#   'at',
#   'Port-Vell',
#   'usually',
#   'around',
#   '4:30pm',
#   'after',
#   'that',
#   'these',
#   'extravagantly',
#   'dressed',
#   'gentlemen',
#   'set',
#   'off',
#   'on',
#   'the',
#   'calvacada',
#   'del',
#   'Reis',
#   'a',
#   'grand',
#   'parade',
#   'of',
#   'floats',
#   'replete',
#   'with',
#   'acrobats',
#   'clowns',
#   'and',
#   'elves',
#   'from',
#   'which',
#   'the',
#   'kings',
#   'dish',
#   'out',
#   'sweets',
#   'to',
#   'local',
#   'kids',
#   'the',
#   'route',
#   'normally',
#   'starts',
#   'at',
#   'the',
#   'lower',
#   'entrance',
#   'of',
#   'parc-de-la-ciutadella',
#   'running',
#   'up',
#   'carrer-de-marques',
#   "del'Argentera-Via",
#   'Laietana',
#   '.',
#   'Carnival',
#   'February/March',
#   'Barcelona',
#   "'s",
#   'carnival',
#   'is',
#   'back',
#   'and',
#   'growing',
#   'in',
#   'popularity',
#   'year',
#   'by',
#   'year',
#   'as',
#   'in',
#   'most',
#   'Catholic',
#   'countries',
#   'carnival',
#   'in',
#   'Spain',
#   'is',
#   'the',
#   'last',
#   'chance',
#   'to',
#   'go',
#   'wild',
#   'before',
#   'Lent',
#   'when',
#   'forty',
#   'days',
#   'of',
#   'abstinence',
#   'kick',
#   'in',
#   'the',
#   'culmination',
#   'of',
#   'the',
#   'party',
#   'is',
#   'la-Gran-Rua-de-Carneval',
#   'when',
#   'visitors',
#   'can',
#   'expect',
#   'to',
#   'see',
#   'plenty',
#   'of',
#   'fancy',
#   'dress',
#   'floats',
#   'and',
#   'fireworks',
#   'form',
#   'a',
#   'grand',
#   'parade',
#   'down',
#   'one',
#   'of',
#   'the',
#   'city',
#   "'s",
#   'main',
#   'streets',
#   'normally',
#   'av-paral-lel',
#   'the',
#   'real',
#   'action',
#   'takes',
#   'place',
#   'down',
#   'the',
#   'road',
#   'in',
#   'Sitges',
#   'a',
#   'picturesque',
#   'coastal',
#   'resort',
#   'famous',
#   'for',
#   'its',
#   'gay',
#   'nightlife',
#   'it',
#   "'s",
#   'debauchery',
#   'of',
#   'the',
#   'first',
#   'order',
#   'with',
#   'half',
#   'of',
#   'Barcelona',
#   "'s",
#   'student',
#   'population',
#   'heading',
#   'down',
#   'on',
#   'the',
#   'train',
#   'in',
#   'fancy',
#   'dress',
#   '.',
#   'dia-de-sant-jordi',
#   '23rd',
#   'April',
#   'St-George-Sant-Jordi',
#   'was',
#   'a',
#   'busy',
#   'man',
#   'and',
#   'not',
#   'only',
#   'did',
#   'he',
#   'gallivant',
#   'about',
#   'the',
#   'English',
#   'countryside',
#   'slaying',
#   'dragons',
#   'but',
#   'occasionally',
#   'he',
#   'would',
#   'be',
#   'called',
#   'upon',
#   'in',
#   'these',
#   'warmer',
#   'climes',
#   'to',
#   'dispatch',
#   'a',
#   'nasty',
#   'lizard',
#   'or',
#   'two',
#   'Such',
#   'heroic',
#   'behaviour',
#   'saw',
#   'him',
#   'dubbed',
#   'patron',
#   'saint',
#   'of',
#   'Catalonia',
#   'and',
#   'his',
#   'festival',
#   'is',
#   'certainly',
#   'one',
#   'of',
#   'the',
#   'most',
#   'colorful',
#   'in',
#   'the',
#   'city',
#   'as',
#   'the',
#   'entire',
#   'length',
#   'of',
#   'las-ramblas',
#   'turns',
#   'into',
#   'a',
#   'flower',
#   'stall',
#   'the',
#   'idea',
#   'being',
#   'that',
#   'men',
#   'should',
#   'purchase',
#   'a',
#   'rose',
#   'for',
#   'the',
#   'dainty',
#   'damsels',
#   'in',
#   'their',
#   'life',
#   'Women',
#   'are',
#   'supposed',
#   'to',
#   'buy',
#   'men',
#   'a',
#   'book',
#   'as',
#   'the',
#   'country',
#   "'s",
#   'legendary',
#   'bard',
#   'Miguel-Cervantes',
#   'died',
#   'on',
#   'this',
#   'day',
#   'it',
#   'is',
#   'a',
#   'sort',
#   'of',
#   'Saint',
#   'Valentine',
#   "'s",
#   'day',
#   'the',
#   'funny',
#   'thing',
#   'is',
#   'that',
#   'they',
#   'mix',
#   'it',
#   'with',
#   'the',
#   'book',
#   'day',
#   'so',
#   'the',
#   'city',
#   'is',
#   'full',
#   'of',
#   'books',
#   'and',
#   'roses',
#   '.',
#   'Formula-One-Spanish-Grand-Prix',
#   'in',
#   'May',
#   'the',
#   'F1',
#   'setup',
#   'roars',
#   'into',
#   'the',
#   'region',
#   'in',
#   'May',
#   'each',
#   'year',
#   'for',
#   'the',
#   'Spanish-Grand-Prix',
#   'which',
#   'takes',
#   'place',
#   'at',
#   'the',
#   'Circuit-de-Catalunya',
#   'in',
#   'Montmelo',
#   '20kms',
#   'outside',
#   'Barcelona',
#   'with',
#   'qualifiers',
#   'engine',
#   'checks',
#   'and',
#   'pretty',
#   'paddock',
#   'girls',
#   'roaming',
#   'around',
#   'this',
#   'becomes',
#   'a',
#   'three',
#   'day',
#   'event',
#   'of',
#   'fuel',
#   'flags',
#   'and',
#   'Ferraris',
#   '.',
#   'Primavera-Sound-Festival',
#   'in',
#   'May/June',
#   'this',
#   'popular',
#   'alternative',
#   'rock',
#   'and',
#   'dance',
#   'festival',
#   'takes',
#   'place',
#   'in',
#   'late',
#   'spring/early',
#   'summer',
#   'each',
#   'year',
#   'at',
#   'Parc-del-Forum',
#   'easily',
#   'accessible',
#   'on',
#   'the',
#   'Northern',
#   'edge',
#   'of',
#   'the',
#   'city',
#   'extensive',
#   'line',
#   'ups',
#   'with',
#   'swathes',
#   'of',
#   'fashionable',
#   'indie',
#   'and',
#   'dance',
#   'a',
#   'real',
#   'music',
#   'lovers',
#   'event',
#   'that',
#   'attracts',
#   'a',
#   'glamorous',
#   'international',
#   'crowd',
#   '.',
#   'Cruilla-Festival',
#   'in',
#   'July',
#   'is',
#   'the',
#   'music',
#   'fest',
#   'with',
#   'the',
#   'broadest',
#   'appeal',
#   'in',
#   'the',
#   'city',
#   'showcasing',
#   'great',
#   'artists',
#   'from',
#   'every',
#   'nation',
#   'genre',
#   'and',
#   'era',
#   'without',
#   'prejudice',
#   'as',
#   'with',
#   'Primavera',
#   'Sound',
#   'the',
#   'action',
#   'takes',
#   'place',
#   'at',
#   'Parc-del-Forum',
#   'in',
#   'easy',
#   'reach',
#   'from',
#   'the',
#   'city',
#   'centre',
#   '.',
#   'The',
#   'costliest',
#   'celebrations',
#   'Sant-Joan',
#   'on',
#   '23rd/24th',
#   'in',
#   'June',
#   'the',
#   'eve',
#   'of',
#   'sant-joan',
#   'aka',
#   'sant-juan/st-john',
#   'depending',
#   'is',
#   'the',
#   'biggest',
#   'party',
#   'night',
#   'of',
#   'the',
#   'year',
#   'this',
#   'midsummer',
#   'celebration',
#   'is',
#   'famed',
#   'for',
#   'it',
#   "'s",
#   'endless',
#   'fireworks',
#   'as',
#   'the',
#   '24th',
#   'is',
#   'a',
#   'public',
#   'holiday',
#   'all',
#   'and',
#   'sundry',
#   'take',
#   'the',
#   'opportunity',
#   'to',
#   'overindulge',
#   'in',
#   'cerveza',
#   'and',
#   'everyone',
#   'except',
#   'granny',
#   'will',
#   'still',
#   'be',
#   'partying',
#   'come',
#   'sunrise',
#   'biggest',
#   'night',
#   'of',
#   'the',
#   'year',
#   'is',
#   'Sant',
#   'Joan',
#   'when',
#   'thousands',
#   'of',
#   'firecrackers',
#   'rockets',
#   'and',
#   'other',
#   'pyrotechnics',
#   'salute',
#   'the',
#   'shortest',
#   'night',
#   'of',
#   'the',
#   'year',
#   'and',
#   'sangria',
#   'calimocho',
#   'and',
#   'cerveza',
#   'flows',
#   'in',
#   'abundance',
#   '.',
#   'Montjuic-de-Nit',
#   'one',
#   'night',
#   'in',
#   'July',
#   'a',
#   'free',
#   'culture',
#   'festival',
#   'on',
#   'the',
#   'idyllic',
#   'mountain',
#   'of',
#   'Montjuic',
#   'this',
#   'summer',
#   'night',
#   'event',
#   'is',
#   'full',
#   'of',
#   'inventive',
#   'entertainment',
#   '.',
#   'The',
#   'most',
#   'famous',
#   'of',
#   'Barcelona',
#   "'s",
#   'district',
#   'festivals',
#   'is',
#   'the',
#   'Festa-Major-de-Gracia',
#   'just',
#   'over',
#   'a',
#   'week',
#   'in',
#   'August',
#   'the',
#   'area',
#   "'s",
#   'streets',
#   'are',
#   'adorned',
#   'with',
#   'wonderful',
#   'papier',
#   'mache',
#   'statues',
#   'woodwork',
#   'ornaments',
#   'and',
#   'decorative',
#   'lanterns',
#   'and',
#   'every',
#   'square',
#   'becomes',
#   'a',
#   'concert',
#   'venue',
#   'as',
#   'the',
#   'fiesta',
#   'gets',
#   'under',
#   'full',
#   'swing',
#   'needless',
#   'to',
#   'say',
#   'drinking',
#   'is',
#   'rife',
#   'as',
#   'bars',
#   'and',
#   'cafes',
#   'heave',
#   'with',
#   'thirsty',
#   'festival',
#   'goers',
#   'and',
#   'many',
#   'more',
#   'swig-al-fresco',
#   'from',
#   'Don-Simon',
#   'cartons',
#   'of',
#   'sangria',
#   '.',
#   'La-Tomatina',
#   'last',
#   'weeks',
#   'of',
#   'August',
#   'one',
#   'of',
#   'Spain',
#   "'s",
#   'most',
#   'talked',
#   'about',
#   'festivals',
#   'is',
#   'the',
#   'entirely',
#   'bonkers',
#   'tomato',
#   'fight',
#   'that',
#   'takes',
#   'place',
#   'each',
#   'year',
#   'in',
#   'Bunol',
#   'just',
#   'outside',
#   'Valencia',
#   'and',
#   'about',
#   '4',
#   'hrs',
#   'drive',
#   'from',
#   'Barcelona',
#   '.',
#   'Starting',
#   'at',
#   '11am',
#   'buses',
#   'leave',
#   'BCN',
#   'sinfully',
#   'early',
#   'in',
#   'the',
#   'morning',
#   'to',
#   'taxi',
#   'punters',
#   'to',
#   'Bunol',
#   'in',
#   'time',
#   'for',
#   'kick',
#   'off',
#   'kind',
#   'of',
#   'like',
#   'Armageddon',
#   'but',
#   'with',
#   'a',
#   'fruity',
#   'twist',
#   '.',
#   'Benicassim-International-festival-FIB',
#   'in',
#   'July',
#   'most',
#   'famous',
#   'international',
#   'music',
#   'festival',
#   'takes',
#   'place',
#   'down',
#   'the',
#   'road',
#   'from',
#   'Barcelona',
#   'in',
#   'benicassim',
#   'a',
#   'port',
#   'town',
#   'just',
#   'outside',
#   'Valencia',
#   'festival',
#   'goers',
#   'typically',
#   'arrive',
#   'several',
#   'days',
#   'early',
#   'to',
#   'camp',
#   'out',
#   '.',
#   'Monegros-Desert-Festival',
#   'one',
#   'night',
#   'in',
#   'July',
#   'Spain',
#   'biggest',
#   'rave',
#   'takes',
#   'place',
#   'one',
#   'very',
#   'long',
#   'night',
#   'in',
#   'July',
#   'every',
#   'year',
#   'more',
#   'than',
#   '40000',
#   'hedonists',
#   'turn',
#   'up',
#   'to',
#   'dance',
#   'to',
#   'world',
#   'class',
#   'acts',
#   'from',
#   'the',
#   'world',
#   'of',
#   'electo',
#   'techno',
#   'drum',
#   'and',
#   'bass',
#   'and',
#   'dubstep',
#   'during',
#   'an',
#   'epic',
#   '22',
#   'hour',
#   'party',
#   'the',
#   'good',
#   'news',
#   'is',
#   'that',
#   'you',
#   'can',
#   'easily',
#   'arrive',
#   'at',
#   'the',
#   'festival',
#   'from',
#   'Barcelona',
#   'thanks',
#   'to',
#   'the',
#   'official',
#   'festival',
#   'bus',
#   '.',
#   'Sanfermines',
#   'on',
#   '6th-14th',
#   'in',
#   'July',
#   'better',
#   'known',
#   'as',
#   'the-running-of-the-Bulls',
#   'expect',
#   'to',
#   'end',
#   'up',
#   'covered',
#   'in',
#   'water',
#   'sangria',
#   'mustard',
#   'soda',
#   'eggs',
#   'you',
#   'name',
#   'it',
#   'the',
#   'opening',
#   'ceremony',
#   'Chupinazo',
#   'of',
#   'the',
#   'festival',
#   'takes',
#   'place',
#   'at',
#   'Plaza-Consistorial',
#   'outside',
#   'of',
#   'City-Hall',
#   'on',
#   'the',
#   'first',
#   'day',
#   'exhilarating',
#   'and',
#   'exhausting',
#   'completely',
#   'mayhem',
#   'huge',
#   'bulls',
#   'run',
#   'by',
#   'quickly',
#   'their',
#   'horns',
#   'white',
#   'and',
#   'sharp',
#   'in',
#   'the',
#   'air',
#   'craziest',
#   'most',
#   'insane',
#   'most',
#   'crowded',
#   'fiesta',
#   '.',
#   'The',
#   'costliest',
#   'celebrations',
#   'take',
#   'place',
#   'during',
#   'the',
#   'day',
#   'of',
#   'the',
#   'Holy-Sant-Joan',
#   'on',
#   '23-June',
#   'and',
#   'on',
#   'the',
#   'day',
#   'of',
#   'the',
#   'festival',
#   'la-Merce',
#   'on',
#   '24-September',
#   'most',
#   'beautiful',
#   'festival',
#   'in',
#   'the',
#   'opinion',
#   'of',
#   'many',
#   'is',
#   'Sant-Jordi-Saint-George',
#   'on',
#   '23-April',
#   '.',
#   'The',
#   'town',
#   'is',
#   'decorated',
#   'with',
#   'roses',
#   'and',
#   'books',
#   'stalls',
#   'on',
#   'this',
#   'day',
#   'you',
#   'should',
#   'not',
#   'miss',
#   'a',
#   'fire',
#   'run',
#   'Correfoc',
#   'Giant',
#   'Gegants',
#   'one',
#   'of',
#   'the',
#   'many',
#   'people',
#   'Towers',
#   'Castellers',
#   'and',
#   'a',
#   'Sardana',
#   'Catalan',
#   'folk',
#   'dance',
#   '.',
#   'Traditionally',
#   'all',
#   'parties',
#   'in',
#   'Barcelona',
#   'as',
#   'in',
#   'Spain',
#   'are',
#   'paused',
#   'twelve',
#   'seconds',
#   'before',
#   '12am',
#   'to',
#   'encourage',
#   'the',
#   'new',
#   'year',
#   'by',
#   'eating',
#   'twelve',
#   'grapes',
#   ...],
#  ['JJ',
#   'CD',
#   'NNP',
#   'NNPS',
#   'CC',
#   'NNPS',
#   'VBP',
#   'JJ',
#   'NNP',
#   'NN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'DT',
#   'JJ',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   'RB',
#   'IN',
#   'CD',
#   'IN',
#   'IN',
#   'DT',
#   'RB',
#   'VBN',
#   'NNS',
#   'VBD',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'NN',
#   'NNP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'VBP',
#   'IN',
#   'NNS',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'WDT',
#   'DT',
#   'NNS',
#   'VBP',
#   'RP',
#   'NNS',
#   'TO',
#   'JJ',
#   'NNS',
#   'DT',
#   'NN',
#   'RB',
#   'VBZ',
#   'IN',
#   'DT',
#   'JJR',
#   'NN',
#   'IN',
#   'NN',
#   'VBG',
#   'RP',
#   'NNS',
#   'JJ',
#   'NNP',
#   '.',
#   'NNP',
#   'NNP',
#   'NNP',
#   'POS',
#   'NN',
#   'VBZ',
#   'RB',
#   'CC',
#   'VBG',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'IN',
#   'JJS',
#   'JJ',
#   'NNS',
#   'VBP',
#   'IN',
#   'NNP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'JJ',
#   'RB',
#   'NNP',
#   'WRB',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'JJ',
#   'WRB',
#   'NNS',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NNS',
#   'CC',
#   'NNS',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'RP',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   'POS',
#   'JJ',
#   'NNS',
#   'RB',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBP',
#   'RP',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'JJ',
#   'IN',
#   'PRP$',
#   'NN',
#   'IN',
#   'PRP',
#   'VBZ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   'POS',
#   'NN',
#   'NN',
#   'VBG',
#   'RP',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   '.',
#   'JJ',
#   'CD',
#   'NNP',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'RB',
#   'RB',
#   'VBD',
#   'PRP',
#   'VB',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'VBG',
#   'NNS',
#   'CC',
#   'RB',
#   'PRP',
#   'MD',
#   'VB',
#   'VBN',
#   'RP',
#   'IN',
#   'DT',
#   'JJR',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'CD',
#   'JJ',
#   'NNS',
#   'VBP',
#   'VBD',
#   'PRP',
#   'VB',
#   'NN',
#   'NN',
#   'IN',
#   'NNP',
#   'CC',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'RB',
#   'CD',
#   'IN',
#   'DT',
#   'RBS',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'PDT',
#   'DT',
#   'NN',
#   'VBG',
#   'IN',
#   'NNS',
#   'MD',
#   'VB',
#   'DT',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBN',
#   'TO',
# ...
#    ('extends', 'NNS'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('pinya', 'NN'),
#    ('-', ':'),
#    ('the', 'DT'),
#    ('crowd', 'NN'),
#    ('of', 'IN'),
#    ('people', 'NNS'),
#    ('below', 'RB'),
#    ('acting', 'VBG'),
#    ('as', 'IN'),
#    ('a', 'DT'),
#    ('base', 'NN'),
#    ('every', 'DT'),
#    ('stage', 'NN'),
#    ('is', 'VBZ'),
#    ('more', 'RBR'),
#    ('precarious', 'JJ'),
#    ('than', 'IN'),
#    ('the', 'DT'),
#    ('last', 'JJ'),
#    ('as', 'IN'),
#    ('the', 'DT'),
#    ('strain', 'NN'),
#    ('on', 'IN'),
#    ('the', 'DT'),
#    ('lower', 'JJR'),
#    ('castellers', 'NNS'),
#    ('becomes', 'NNS'),
#    ('greater', 'JJR'),
#    ('with', 'IN'),
#    ('every', 'DT'),
#    ('passing', 'NN'),
#    ('minute', 'VBZ'),
#    ('the', 'DT'),
#    ('castellers', 'NNS'),
#    ('represent', 'VBP'),
#    ('the', 'DT'),
#    ('strength', 'NN'),
#    ('balance', 'NN'),
#    ('courage', 'NN'),
#    ('and', 'CC'),
#    ('common', 'JJ'),
#    ('sense', 'NN'),
#    ('ingrained', 'VBN'),
#    ('into', 'IN'),
#    ('the', 'DT'),
#    ('people', 'NNS'),
#    ('of', 'IN'),
#    ('Catalonia', 'NNP'),
#    ('.', '.')],
#   [('Deda-de-los-Reyes-Magos', 'JJ'),
#    ("-Kings'-Day", 'NN'),
#    ('in', 'IN'),
#    ('January', 'NNP'),
#    ('major', 'JJ'),
#    ('public', 'JJ'),
#    ('holiday', 'NN'),
#    ('is', 'VBZ'),
#    ('also', 'RB'),
#    ('the', 'DT'),
#    ('biggest', 'JJS'),
#    ('Christmas', 'NNP'),
#    ('parade', 'NN'),
#    ('in', 'IN'),
#    ('Spain', 'NNP'),
#    ('it', 'PRP'),
#    ("'s", 'VBZ'),
#    ('held', 'VBN'),
#    ('in', 'IN'),
#    ('early', 'JJ'),
#    ('January', 'NNP'),
#    ('the', 'DT'),
#    ('festival', 'NN'),
#    ('celebrates', 'VBZ'),
#    ('the', 'DT'),
#    ('arrival', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('three', 'CD'),
#    ('kings', 'NNS'),
#    ('in', 'IN'),
#    ('Bethlehem', 'NNP'),
#    ('with', 'IN'),
#    ('gifts', 'NNS'),
#    ('for', 'IN'),
#    ('baby', 'NN'),
#    ('Jesus', 'NNP'),
#    ('and', 'CC'),
#    ('this', 'DT'),
#    ('is', 'VBZ'),
#    ('the', 'DT'),
#    ('traditional', 'JJ'),
#    ('day', 'NN'),
#    ('for', 'IN'),
#    ('exchanging', 'VBG'),
#    ('Christmas', 'NNP'),
#    ('gifts', 'NNS'),
#    ('in', 'IN'),
#    ('Spain', 'NNP'),
#    ('a', 'DT'),
#    ('sensory', 'JJ'),
#    ('stunning', 'JJ'),
#    ('reception', 'NN'),
#    ('when', 'WRB'),
#    ('the', 'DT'),
#    ('three', 'CD'),
#    ('kings', 'NNS'),
#    ('arrive', 'VBP'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ("'s", 'POS'),
#    ('port', 'NN'),
#    ('aboard', 'IN'),
#    ('the', 'DT'),
#    ('special', 'JJ'),
#    ('ship', 'NN'),
#    ('santa-euleolia', 'JJ'),
#    ('expect', 'NN'),
#    ('fireworks', 'NNS'),
#    ('canons', 'NNS'),
#    ('.', '.'),
#    ('The', 'DT'),
#    ('Calcotada', 'NNP'),
#    ('in', 'IN'),
#    ('February', 'NNP'),
#    ('you', 'PRP'),
#    ("'re", 'VBP'),
#    ('in', 'IN'),
#    ('for', 'IN'),
#    ('a', 'DT'),
#    ('real', 'JJ'),
#    ('culinary', 'JJ'),
#    ('treat', 'NN'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('traditional', 'JJ'),
#    ('Catalan', 'NNP'),
#    ('feast', 'VBD'),
#    ('held', 'VBN'),
#    ('mostly', 'RB'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('second', 'JJ'),
#    ('month', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('year', 'NN'),
#    ('but', 'CC'),
#    ('sometimes', 'RB'),
#    ('in', 'IN'),
#    ('March', 'NNP'),
#    ('because', 'IN'),
#    ('it', 'PRP'),
#    ('all', 'DT'),
#    ('depends', 'VBZ'),
#    ('on', 'IN'),
#    ('the', 'DT'),
#    ('early', 'JJ'),
#    ('harvest', 'NN'),
#    ('early', 'JJ'),
#    ('spring', 'NN'),
#    ('might', 'MD'),
#    ('seem', 'VB'),
#    ('like', 'IN'),
#    ('an', 'DT'),
#    ('odd', 'JJ'),
#    ('time', 'NN'),
#    ('for', 'IN'),
#    ('a', 'DT'),
#    ('harvest', 'NN'),
#    ('festival', 'NN'),
#    ('but', 'CC'),
#    ('this', 'DT'),
#    ('celebration', 'NN'),
#    ('is', 'VBZ'),
#    ('all', 'DT'),
#    ('about', 'IN'),
#    ('spring', 'NN'),
#    ('onions', 'NNS'),
#    ('everyone', 'NN'),
#    ('at', 'IN'),
#    ('this', 'DT'),
#    ('citywide', 'JJ'),
#    ('event', 'NN'),
#    ('wears', 'VBZ'),
#    ('a', 'DT'),
#    ('bib', 'NN'),
#    ('and', 'CC'),
#    ('gets', 'VBZ'),
#    ('messy', 'VBN'),
#    ('in', 'IN'),
#    ('all', 'PDT'),
#    ('the', 'DT'),
#    ('right', 'JJ'),
#    ('ways', 'NNS'),
#    ('with', 'IN'),
#    ('classic', 'JJ'),
#    ('Spanish', 'JJ'),
#    ('dips', 'NNS'),
#    ('and', 'CC'),
#    ('incarnations', 'NNS'),
#    ('of', 'IN'),
#    ('onions', 'NNS'),
#    ('that', 'IN'),
#    ('you', 'PRP'),
#    ('ca', 'MD'),
#    ("n't", 'RB'),
#    ('even', 'RB'),
#    ('imagine', 'VB'),
#    ('.', '.'),
#    ('Barcelona', 'NNP'),
#    ('Carnival', 'NNP'),
#    ('in', 'IN'),
#    ('February/March', 'NNP'),
#    ('this', 'DT'),
#    ('week', 'NN'),
#    ('long', 'RB'),
#    ('carnival', 'NN'),
#    ('is', 'VBZ'),
#    ('Barcelona', 'NNP'),
#    ("'s", 'POS'),
#    ('equivalent', 'NN'),
#    ('of', 'IN'),
#    ('Mardi-Gras', 'NNP'),
#    ('and', 'CC'),
#    ('it', 'PRP'),
#    ("'s", 'VBZ'),
#    ('free', 'JJ'),
#    ('to', 'TO'),
#    ('attend', 'VB'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('historical', 'JJ'),
#    ('tradition', 'NN'),
#    ('that', 'WDT'),
#    ('takes', 'VBZ'),
#    ('place', 'NN'),
#    ('on', 'IN'),
#    ('the', 'DT'),
#    ('streets', 'NNS'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ('with', 'IN'),
#    ('over', 'IN'),
#    ('30', 'CD'),
#    ('parades', 'NNS'),
#    ('dancing', 'VBG'),
#    ('and', 'CC'),
#    ('costumes', 'NNS'),
#    ('floats', 'NNS'),
#    ('orange', 'VBP'),
#    ('balloons', 'NNS'),
#    ('a', 'DT'),
#    ('firework', 'NN'),
#    ('show', 'NN'),
#    ('in', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('at', 'IN'),
#    ('the', 'DT'),
#    ('end', 'NN'),
#    ('of', 'IN'),
#    ('February', 'NNP'),
#    ('get', 'VB'),
#    ('yourself', 'PRP'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('centre', 'NN'),
#    ('of', 'IN'),
#    ('town', 'NN'),
#    ('and', 'CC'),
#    ('let', 'VB'),
#    ('the', 'DT'),
#    ('streets', 'NNS'),
#    ('do', 'VBP'),
#    ('the', 'DT'),
#    ('talking', 'VBG'),
#    ('the', 'DT'),
#    ('first', 'JJ'),
#    ('day', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('Carnival', 'NNP'),
#    ('starts', 'VBZ'),
#    ('with', 'IN'),
#    ('an', 'DT'),
#    ('abundance', 'NN'),
#    ('of', 'IN'),
#    ('food', 'NN'),
#    ('markets', 'NNS'),
#    ('all', 'DT'),
#    ('over', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ('.', '.'),
#    ('Festa-de-Sant-Medir', 'JJ'),
#    ('Candy-Festival', 'JJ'),
#    ('in', 'IN'),
#    ('March', 'NNP'),
#    ('this', 'DT'),
#    ('epic', 'NN'),
#    ('parade', 'NN'),
#    ('between', 'IN'),
#    ('carrer-de-san-salvador', 'NN'),
#    ('and', 'CC'),
#    ('gran-de-greocia', 'NN'),
#    ('the', 'DT'),
#    ('procession', 'NN'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('mardis-gras', 'NN'),
#    ('of', 'IN'),
#    ('sorts', 'NNS'),
#    ('and', 'CC'),
#    ('an', 'DT'),
#    ('occasion', 'NN'),
#    ('where', 'WRB'),
#    ('an', 'DT'),
#    ('obscene', 'JJ'),
#    ('amount', 'NN'),
#    ('of', 'IN'),
#    ('free', 'JJ'),
#    ('sweets', 'NNS'),
#    ('are', 'VBP'),
#    ('thrown', 'VBN'),
#    ('out', 'IN'),
#    ('to', 'TO'),
#    ('the', 'DT'),
#    ('crowds', 'NN'),
#    ('lining', 'VBG'),
#    ('the', 'DT'),
#    ('route', 'NN'),
#    ('.', '.'),
#    ('Feria-de-abril', 'NNP'),
#    ('in', 'IN'),
#    ('April', 'NNP'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('weeklong', 'JJ'),
#    ('flamenco', 'NN'),
#    ('festival', 'NN'),
#    ('that', 'WDT'),
#    ('follows', 'VBZ'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('aftermath', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ("'s", 'POS'),
#    ('mega', 'JJ'),
#    ('Easter', 'NNP'),
#    ('celebrations', 'NNS'),
#    ('can', 'MD'),
#    ('expect', 'VB'),
#    ('a', 'DT'),
#    ('showcase', 'NN'),
#    ('of', 'IN'),
#    ('all', 'DT'),
#    ('things', 'NNS'),
#    ('Spanish', 'JJ'),
#    ('with', 'IN'),
#    ('horse', 'NN'),
#    ('riders', 'NNS'),
#    ('fun', 'VBP'),
#    ('fairs', 'NNS'),
#    ('and', 'CC'),
#    ('good', 'JJ'),
#    ('times', 'NNS'),
#    ('galore', 'VBP'),
#    ('highlights', 'NNS'),
#    ('include', 'VBP'),
#    ('paella', 'JJ'),
#    ('dishes', 'NNS'),
#    ('that', 'WDT'),
#    ('are', 'VBP'),
#    ('the', 'DT'),
#    ('size', 'NN'),
#    ('of', 'IN'),
#    ('a', 'DT'),
#    ('small', 'JJ'),
#    ('car', 'NN'),
#    ('and', 'CC'),
#    ('a', 'DT'),
#    ('Ferris', 'NNP'),
#    ('wheel', 'NN'),
#    ('offering', 'VBG'),
#    ('some', 'DT'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('best', 'JJS'),
#    ('views', 'NNS'),
#    ('over', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ('.', '.')],
#   [('Formula-One', 'NN'),
#    ('in', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('in', 'IN'),
#    ('May', 'NNP'),
#    ('biggest', 'JJS'),
#    ('motorcar', 'NN'),
#    ('race', 'NN'),
#    ('on', 'IN'),
#    ('the', 'DT'),
#    ('planet', 'NN'),
#    ('and', 'CC'),
#    ('enjoy', 'VB'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ("'s", 'POS'),
#    ('best', 'JJS'),
#    ('drivers', 'NNS'),
#    ('navigating', 'VBG'),
#    ('one', 'CD'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('tightest', 'NN'),
#    ('tracks', 'NNS'),
#    ('around', 'RP'),
#    ('then', 'RB'),
#    ('get', 'VB'),
#    ('yourself', 'PRP'),
#    ('to', 'TO'),
#    ('Barcelona', 'NNP'),
#    ('for', 'IN'),
#    ('this', 'DT'),
#    ('annual', 'JJ'),
#    ('automobile', 'NN'),
#    ('highlight', 'VBD'),
#    ('held', 'VBN'),
#    ('at', 'IN'),
#    ('the', 'DT'),
#    ('montmelo', 'NN'),
#    ('racetrack', 'NN'),
#    ('.', '.'),
#    ('Fiesta-de-Barceloneta', 'NN'),
#    ('in', 'IN'),
#    ('June', 'NNP'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('part', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('Fiesta-del-barrio', 'NNP'),
#    ('summer', 'NN'),
#    ('festival', 'NN'),
#    ('series', 'NN'),
#    ('celebrating', 'VBG'),
#    ('the', 'DT'),
#    ('individual', 'JJ'),
#    ('city', 'NN'),
#    ('districts', 'NNS'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('huge', 'JJ'),
#    ('party', 'NN'),
#    ('featuring', 'VBG'),
#    ('papier', 'JJR'),
#    ('figures', 'NNS'),
#    ('and', 'CC'),
#    ('sculptures', 'NNS'),
#    ('prizes', 'NNS'),
#    ('for', 'IN'),
#    ('the', 'DT'),
#    ('best', 'JJS'),
#    ('decorated', 'JJ'),
#    ('street', 'NN'),
#    ('traditional', 'JJ'),
#    ('castellers', 'NNS'),
#    ('human', 'JJ'),
#    ('castles', 'NNS'),
#    ('dancing', 'VBG'),
#    ('devils', 'NNS'),
#    ('drummers', 'NNS'),
#    ('fireworks', 'NNS'),
#    ('and', 'CC'),
#    ('the', 'DT'),
#    ('giants', 'NNS'),
#    ('parade', 'NN'),
#    ('.', '.')],
#   [('Sonar', 'NNP'),
#    ('Festival', 'NNP'),
#    ('in', 'IN'),
#    ('June', 'NNP'),
#    ('three', 'CD'),
#    ('day', 'NN'),
#    ('electronic', 'JJ'),
#    ('arts', 'NNS'),
#    ('festival', 'NN'),
#    ('in', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('runs', 'VBZ'),
#    ('all', 'DT'),
#    ('day', 'NN'),
#    ('and', 'CC'),
#    ('night', 'NN'),
#    ('one', 'CD'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ("'s", 'POS'),
#    ('biggest', 'JJS'),
#    ('celebrations', 'NNS'),
#    ('of', 'IN'),
#    ('electronic', 'JJ'),
#    ('music', 'NN'),
#    ('with', 'IN'),
#    ('stellar', 'JJ'),
#    ('acts', 'NNS'),
#    ('.', '.'),
#    ('Monegros', 'NNP'),
#    ('in', 'IN'),
#    ('July', 'NNP'),
#    ('is', 'VBZ'),
#    ('the', 'DT'),
#    ('biggest', 'JJS'),
#    ('Electronic', 'JJ'),
#    ('music', 'NN'),
#    ('festival', 'NN'),
#    ('and', 'CC'),
#    ('rave', 'VB'),
#    ('in', 'IN'),
#    ('Spain', 'NNP'),
#    ('and', 'CC'),
#    ('it', 'PRP'),
#    ("'s", 'VBZ'),
#    ('held', 'VBN'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('desert', 'NN'),
#    ('just', 'RB'),
#    ('outside', 'IN'),
#    ('of', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('a', 'DT'),
#    ('festival', 'NN'),
#    ('that', 'WDT'),
#    ("'s", 'VBZ'),
#    ('been', 'VBN'),
#    ('compared', 'VBN'),
#    ('to', 'TO'),
#    ('Burning', 'NNP'),
#    ('Man', 'NNP'),
#    ('in', 'IN'),
#    ('Nevada', 'NNP'),
#    ('for', 'IN'),
#    ('it', 'PRP'),
#    ("'s", 'VBZ'),
#    ('intensity', 'JJ'),
#    ('attendees', 'NNS'),
#    ('can', 'MD'),
#    ('expect', 'VB'),
#    ('to', 'TO'),
#    ('enjoy', 'VB'),
#    ('the', 'DT'),
#    ('fine', 'JJ'),
#    ('company', 'NN'),
#    ('of', 'IN'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('40000', 'CD'),
#    ('party', 'NN'),
#    ('people', 'NNS'),
#    ('for', 'IN'),
#    ('over', 'IN'),
#    ('22', 'CD'),
#    ('hours', 'NNS'),
#    ('of', 'IN'),
#    ('nonstop', 'JJ'),
#    ('music', 'NN'),
#    ('.', '.'),
#    ('Benicassim', 'NNP'),
#    ('in', 'IN'),
#    ('July', 'NNP'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('festival', 'NN'),
#    ('does', 'VBZ'),
#    ("n't", 'RB'),
#    ('actually', 'RB'),
#    ('take', 'VB'),
#    ('place', 'NN'),
#    ('in', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('but', 'CC'),
#    ('the', 'DT'),
#    ('Spanish', 'JJ'),
#    ('town', 'NN'),
#    ('benicassim', 'NN'),
#    ('is', 'VBZ'),
#    ('about', 'IN'),
#    ('2', 'CD'),
#    ('and', 'CC'),
#    ('a', 'DT'),
#    ('half', 'JJ'),
#    ('hours', 'NNS'),
#    ('away', 'RB'),
#    ('by', 'IN'),
#    ('train', 'NN'),
#    ('and', 'CC'),
#    ('the', 'DT'),
#    ('festival', 'NN'),
#    ('is', 'VBZ'),
#    ('aptly', 'RB'),
#    ('named', 'VBN'),
#    ('after', 'IN'),
#    ('the', 'DT'),
#    ('town', 'NN'),
#    ('a', 'DT'),
#    ('huge', 'JJ'),
#    ('annual', 'JJ'),
#    ('music', 'NN'),
#    ('festival', 'NN'),
#    ('and', 'CC'),
#    ('well', 'RB'),
#    ('worth', 'IN'),
#    ('the', 'DT'),
#    ('journey', 'NN'),
#    ('down', 'RP'),
#    ('south', 'RB'),
#    ('best', 'JJS'),
#    ('part', 'NN'),
#    ('is', 'VBZ'),
#    ('people', 'NNS'),
#    ('camp', 'VBP'),
#    ('out', 'RP'),
#    ('in', 'IN'),
#    ('tents', 'NNS'),
#    ('just', 'RB'),
#    ('10', 'CD'),
#    ('minutes', 'NNS'),
#    ('walk', 'VBP'),
#    ('from', 'IN'),
#    ('the', 'DT'),
#    ('beach', 'NN'),
#    ('.', '.'),
#    ('Circuit-Festival-Barcelona', 'NN'),
#    ('in', 'IN'),
#    ('August', 'NNP'),
#    ('is', 'VBZ'),
#    ('an', 'DT'),
#    ('international', 'JJ'),
#    ('Gay', 'NNP'),
#    ('and', 'CC'),
#    ('Lesbian', 'NNP'),
#    ('festival', 'NN'),
#    ('explodes', 'VBZ'),
#    ('into', 'IN'),
#    ('venues', 'NNS'),
#    ('across', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('and', 'CC'),
#    ('in', 'IN'),
#    ('nearby', 'JJ'),
#    ('cities', 'NNS'),
#    ('is', 'VBZ'),
#    ('held', 'VBN'),
#    ('over', 'IN'),
#    ('a', 'DT'),
#    ('week', 'NN'),
#    ('and', 'CC'),
#    ('celebrates', 'VBZ'),
#    ('the', 'DT'),
#    ('championing', 'NN'),
#    ('of', 'IN'),
#    ('equality', 'NN'),
#    ('music', 'NN'),
#    ('arts', 'NNS'),
#    ('and', 'CC'),
#    ('sports', 'NNS'),
#    ('with', 'IN'),
#    ('pre-parties', 'JJ'),
#    ('parties', 'NNS'),
#    ('and', 'CC'),
#    ('post', 'NN'),
#    ('parties', 'NNS'),
#    ('is', 'VBZ'),
#    ('the', 'DT'),
#    ('biggest', 'JJS'),
#    ('European', 'JJ'),
#    ('gay', 'NN'),
#    ('and', 'CC'),
#    ('lesbian', 'JJ'),
#    ('event', 'NN'),
#    ('ever', 'RB'),
#    ('attracting', 'VBG'),
#    ('more', 'JJR'),
#    ('than', 'IN'),
#    ('50000', 'CD'),
#    ('visitors', 'NNS'),
#    ('from', 'IN'),
#    ('all', 'DT'),
#    ('over', 'IN'),
#    ('the', 'DT'),
#    ('world', 'NN'),
#    ('.', '.'),
#    ('Fiesta-de-la-Merce', 'NN'),
#    ('in', 'IN'),
#    ('September', 'NNP'),
#    ('is', 'VBZ'),
#    ('a', 'DT'),
#    ('celebration', 'NN'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('city', 'NN'),
#    ("'s", 'POS'),
#    ('patron', 'NN'),
#    ('saint', 'NN'),
#    ('and', 'CC'),
#    ('protector', 'NN'),
#    ('of', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('street', 'NN'),
#    ('parties', 'NNS'),
#    ('elaborate', 'VBP'),
#    ('decorations', 'NNS'),
#    ('free', 'JJ'),
#    ('music', 'NN'),
#    ('concerts', 'VBZ'),
#    ('breath', 'NN'),
#    ('taking', 'VBG'),
#    ('fire', 'NN'),
#    ('shows', 'NNS'),
#    ('and', 'CC'),
#    ('wondrous', 'JJ'),
#    ('processions', 'NNS'),
#    ('of', 'IN'),
#    ('giants', 'NNS'),
#    ('and', 'CC'),
#    ('human', 'JJ'),
#    ('castles', 'NNS'),
#    ('highlights', 'NNS'),
#    ('of', 'IN'),
#    ('the', 'DT'),
#    ('la-merce-festival', 'NN'),
#    ('is', 'VBZ'),
#    ('the', 'DT'),
#    ('Correfoc', 'NNP'),
#    ('fire-runs', 'VBZ'),
#    ('a', 'DT'),
#    ('special', 'JJ'),
#    ('community', 'NN'),
#    ('in', 'IN'),
#    ('Barcelona', 'NNP'),
#    ('dress', 'NN'),
#    ('up', 'RB'),
#    ('as', 'IN'),
#    ('devils', 'NNS'),
#    ('and', 'CC'),
#    ('run', 'VB'),
#    ('the', 'DT'),
#    ('streets', 'NNS'),
#    ('with', 'IN'),
#    ('handheld', 'NN'),
#    ('fireworks', 'NNS'),
#    ('and', 'CC'),
#    ('bangers', 'NNS'),
#    ('they', 'PRP'),
#    ('set', 'VBP'),
#    ('them', 'PRP'),
#    ('off', 'RP'),
#    ('in', 'IN'),
#    ('the', 'DT'),
#    ('air', 'NN'),
#    ('accompanied', 'VBN'),
#    ('by', 'IN'),
#    ('fire', 'NN'),
#    ('breathing', 'NN'),
#    ('dragons', 'NNS'),
#    ('.', '.'),
#    ('Criola-Beach-Festival', 'JJ'),
#    ('in', 'IN'),
#    ('Jun-2018', 'NNP'),
#    ('.', '.')],
#   [('La-Merc', 'JJ'), ('in', 'IN'), ('Sep-2018', 'NNP'), ('.', '.')],
#   [('Wanderlust108', 'NNP'), ('in', 'IN'), ('Oct-2018', 'NNP'), ('.', '.')],
#   [('MIRA-Festival', 'JJ'), ('in', 'IN'), ('Nov-2018', 'NNP'), ('.', '.')]])

# %%
from collections import defaultdict
from operator import itemgetter

def viterbi(values_from_hmm):#output from the above function: hmm_viterbi are assigned to the following four variables
    my_dict = defaultdict(list)
    emission_probability=values_from_hmm[0]
    transition_probability=values_from_hmm[1]
    observations=values_from_hmm[2]#words
    states=values_from_hmm[3]#tags
    word_tag_from_doc=values_from_hmm[4]
    
    new_path = []
    already_path=[]
    prob_previous=0
    previous_tag=None
    result_newpath=[]
    
 
    #print(states)
    
    # Add the probabilities of beginning the sequence with each possible state  
        
#     for i in range(len(word_tag_from_doc)):#i need res to get the list of items - i have to loop through that list of lists
        #print(i)
    for e in word_tag_from_doc:#i use this to have access to the list of lists
        already_path.append(e)
        for (a, b) in e:
                #print(a)
                #print(a)
            if a == e[0][0]:#meaning if a is the first word of every list
                if a in emission_probability:#i use this because this is the one that's calculated by using HMM
                    for itc in emission_probability[a]:
                            #print(itc)
                        present_tag=itc[0]#corresponding current tag according to hmm word_tag directory
                            #print(present_tag)
                        present_val=itc[1]#corresponding current tag value of the word that i am looping through    
                        max_cal=[]
                        max_cal.append(((present_val*1), present_tag))
                        #already_path.append((a,present_tag))
#                             print(already_path)
                    anw = sorted(max_cal, key=lambda x: x, reverse=True)[0]#check whether the value was output in a list if yes add [0]                    
                        #print(anw)
                    previous_tag=anw[1]
                            #print(previous_tag)
                    prob_previous=anw[0]
                            #print(prob_previous)
                        #already_path.append(((a,previous_tag)))
                    new_path.append([])
                    i = len(new_path)-1
                    new_path[i].append((a, previous_tag))
                        #print(already_path)
                      
            else:         
                if a in emission_probability:#i use this because this is the one that's calculated by using HMM
                    for itc in emission_probability[a]:
                            #print(itc)
                        present_tag=itc[0]#corresponding current tag according to hmm word_tag directory
                            #print(present_tag)
                        present_val=itc[1]#corresponding current tag value of the word that i am looping through
                            #print(present_val)
                            #print(transition_probability[previous_tag])
                            #already_path.append((a,present_tag))
                        try:
                            ans=float([item[1] for item in transition_probability[previous_tag] if present_tag in item][0])
                            #print(ans)
                        except IndexError: ## not the best way to code...do not catch exceptions, but this is an exception to the exception catching rule
                            ans=0.1
                        max_cal=[]
                        max_cal.append(((present_val*prob_previous*ans), present_tag))#sample
                    
                    anw = sorted(max_cal, key=lambda x: x, reverse=True)[0]#check whether the value was output in a list if yes add [0]                    
                            #print(anw)
                    previous_tag=anw[1]
                    prob_previous=anw[0]
                        #print(prob_previous)
                        #print(previous_tag) 
                        #already_path.append((a, previous_tag))
                        
                    new_path[i].append((a, previous_tag))
            
    return(new_path)

# %%
#extracting information/relationship-using nltk.ne_chunk

from nltk.sem.relextract import tree2semi_rel, semi_rel2reldict
import pandas as pd
from datetime import date
document=viterbi(hmm_viterbi(reading_file('/Users/chidam/Desktop/Barcelona.csv')))
chunk_result=[]
for i in document:
    res=nltk.ne_chunk(i)
    chunk_result.append(semi_rel2reldict(tree2semi_rel(res)))
    #print(chunk_result)
result=[]
for veg in chunk_result:
    for carrot in veg:
        result.append([])
        i = len(result)-1
        result[i].append((carrot['untagged_filler']))
        #carrot['subjtext'], carrot['objtext'], carrot['rcon'], 
result

#this section is write the results into a file:
# with open ('/Users/chidam/Desktop/Barcelona.txt', 'a') as f:
#     for line in result:   
#         f.write(str(line))
# Out:
# [["usually around 4:30pm after that these extravagantly dressed gentlemen set off on the calvacada del Reis a grand parade of floats replete with acrobats clowns and elves from which the kings dish out sweets to local kids the route normally starts at the lower entrance of parc-de-la-ciutadella running up carrer-de-marques del'Argentera-Via Laietana ."],
#  ['February/March'],
#  ["'s carnival is back and growing in popularity year by year as in most"],
#  ['countries carnival in'],
#  ["is the last chance to go wild before Lent when forty days of abstinence kick in the culmination of the party is la-Gran-Rua-de-Carneval when visitors can expect to see plenty of fancy dress floats and fireworks form a grand parade down one of the city 's main streets normally av-paral-lel the real action takes place down the road in"],
#  ['countryside slaying dragons but occasionally he would be called upon in these warmer climes to dispatch a nasty lizard or two Such heroic behaviour saw him dubbed patron saint of'],
#  ['easily accessible on the'],
#  ['edge of the city extensive line ups with swathes of fashionable indie and dance a real music lovers event that attracts a glamorous international crowd . Cruilla-Festival in'],
#  ['is the music fest with the broadest appeal in the city showcasing great artists from every nation genre and era without prejudice as with'],
#  ['the action takes place at'],
#  ['last weeks of August one of'],
#  ["'s most talked about festivals is the entirely bonkers tomato fight that takes place each year in Bunol just outside"],
#  ['one of the many people'],
#  ['old-port the'],
#  ['land with their ship and move while making a long procession through the city their train is lined with old and young and they throw candies to the children they awake in the morning of the 6-January with their gifts which the holy-three-kings brought . The festival of Sant-Medir takes place during the first week of March a long procession of pack animals and riders on the most beautiful horses meets at Plaza-Rius-i-Taulet in the district of'],
#  ['and'],
#  ['festivals like'],
#  ["'s biggie La-Merce on 24-Sep the correfoc or fire-run represents the epic battle between good and evil"],
#  ['de diablos or groups of devils dance to drums push giant beasts through the streets and light fireworks on pitchforks the devil dancers then weave through the crowd spewing sparks everywhere this celebration fills the streets with fire and festivity energy is infectious . The ball-de-bastons is a Catalan-folk dance that involves dancers hitting sticks together dancers will have one or two sticks made of oak and they perform different patterns of stick clashing while standing in two rows dancers are dressed all white with red sashes and accompanied by a band made of tabor pipes or bagpipes the dance can be seen at any traditional'],
#  ['festival the sardana dance is a traditional symbol of'],
#  ['traditions is the castells or human-towers it has become a staple for'],
#  ['festivals teams that compete to see who can create the best human tower are called colles-castellers for a tower of any formation to be successfully completed a single child must climb to the top raise one arm and hold up four fingers said to represent the four stripes of the'],
#  ["it 's held in early January the festival celebrates the arrival of the three kings in"],
#  ['with gifts for baby'],
#  ['and this is the traditional day for exchanging Christmas gifts in'],
#  ["a sensory stunning reception when the three kings arrive in the city 's port aboard the special ship santa-euleolia expect fireworks canons . The"],
#  ["in February you 're in for a real culinary treat is a traditional"],
#  ['feast held mostly in the second month of the year but sometimes in March because it all depends on the early harvest early spring might seem like an odd time for a harvest festival but this celebration is all about spring onions everyone at this citywide event wears a bib and gets messy in all the right ways with classic'],
#  ["dips and incarnations of onions that you ca n't even imagine ."],
#  ['in February/March this week long carnival is'],
#  ["'s equivalent of Mardi-Gras and it 's free to attend is a historical tradition that takes place on the streets of the city with over 30 parades dancing and costumes floats orange balloons a firework show in"],
#  ['at the end of February get yourself to the centre of town and let the streets do the talking the first day of the'],
#  ['starts with an abundance of food markets all over the city . Festa-de-Sant-Medir Candy-Festival in March this epic parade between carrer-de-san-salvador and gran-de-greocia the procession is a mardis-gras of sorts and an occasion where an obscene amount of free sweets are thrown out to the crowds lining the route . Feria-de-abril in'],
#  ["is a weeklong flamenco festival that follows in the aftermath of the city 's mega Easter celebrations can expect a showcase of all things"],
#  [''],
#  ['in June three day electronic arts festival in'],
#  ["runs all day and night one of the world 's biggest celebrations of electronic music with stellar acts ."],
#  ['in'],
#  ['is the biggest Electronic music festival and rave in'],
#  ["and it 's held in the desert just outside of"],
#  ["a festival that 's been compared to"],
#  ['Man in'],
#  ["for it 's intensity attendees can expect to enjoy the fine company of more than 40000 party people for over 22 hours of nonstop music ."],
#  ['in'],
#  ["is a festival does n't actually take place in"],
#  ['but the'],
#  ['town benicassim is about 2 and a half hours away by train and the festival is aptly named after the town a huge annual music festival and well worth the journey down south best part is people camp out in tents just 10 minutes walk from the beach . Circuit-Festival-Barcelona in'],
#  ['is an international Gay and'],
#  ['festival explodes into venues across'],
#  ['and in nearby cities is held over a week and celebrates the championing of equality music arts and sports with pre-parties parties and post parties is the biggest'],
#  ["gay and lesbian event ever attracting more than 50000 visitors from all over the world . Fiesta-de-la-Merce in September is a celebration of the city 's patron saint and protector of"],
#  ['street parties elaborate decorations free music concerts breath taking fire shows and wondrous processions of giants and human castles highlights of the la-merce-festival is the']]
